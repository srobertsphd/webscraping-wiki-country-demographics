# %% [markdown]
# # Wiki Country Demographics Webscraping Project
#
# * So here is a link to the assignment:
# https://jovian.ai/learn/zero-to-data-analyst-bootcamp/assignment/project-1-web-scraping-with-python
#
#
# * And here is a link to a Wiki list of all countries by population:
# https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population
# ... It looks like if I crawl the links in this table I can reach the particular spellings and format of each of the demographic webpages
#
#
#
# * Some Wiki Demographics pages like these Have an easy table to access which has the info I want to scrape
#     * https://en.wikipedia.org/wiki/Demographics_of_Switzerland
#     * https://en.wikipedia.org/wiki/Demographics_of_the_United_States
#     * https://en.wikipedia.org/wiki/Demographics_of_Chile
#
#
# * Some Demographics pages like these have the info in a different format:
#     * https://en.wikipedia.org/wiki/Demography_of_Australia
#
#
# * Some pages like these do not have these secific summary tables at all:
#     * https://en.wikipedia.org/wiki/Demographics_of_Kenya
#     * https://en.wikipedia.org/wiki/Demographics_of_Thailand
#     * https://en.wikipedia.org/wiki/Demographics_of_Italy

# %% [markdown]
# # Methods of Scraping these Wiki sites
#
# 1. write some code to handle the cases where the tables exist
# 2. handle with error messages the instances where the relevant tables do not exist
# 3. read ALL of the table in and make a dictionary of values
# 4. read this into a CSV file that can be handled by Pandas
# 5. Crawl the list of countries in wiki and see how many countries I can retrieve information for
# 6. Look at the pages I could not get info for and see if there is some 2nd order way to scrape some of the data

# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %% [markdown]
# # This is scraping all the link and info from the list of countries
# * Things to improve: User the headers to write the keys for the get_row_values function

# %%
# now lets get all of the countries from the table
# ths is from the table at https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population

def get_headers(table_header_row):
    cols = []
    for col in table_header_row:
        cols.append(col.text.strip()) 
    return cols[:4] # we dont want the date or the source

def get_row_values(country): 
    info = {
            'rank': country.th.text.strip(),
            'link': country.a['href'],
            'name': country.a.text.strip(),
            'population': country.find('td', style='text-align:right').text.strip().replace(',',""),
            'percent_of_world': country.find_all('td', align='right').text[:-1]
           }
    return info

def build_country_list(rows):
    country_list = []
    for row in rows:
        country_list.append(get_row_values(row))
    return country_list

def scrape_wiki_table():
    world_countries_url = 'https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population'
    soup = BeautifulSoup(requests.get(world_countries_url).text)
    tables = soup.find_all('table', class_='wikitable sortable plainrowheaders')
    rows = tables[0].find_all('tr')
    #headers = get_headers(rows[0].find_all('th'))
    return build_country_list(rows[1:242])

def write_country_csv(path, country_list):
    df = pd.DataFrame(country_list)
    df.to_csv(path, index=False, header=True)

# %%
country_list = scrape_wiki_table()
write_country_csv('country_list.csv', country_list)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-b996318ba641> in <module>
# ----> 1 country_list = scrape_wiki_table()
#       2 write_country_csv('country_list.csv', country_list)
#
# <ipython-input-16-a39e0b8eff51> in scrape_wiki_table()
#      30     rows = tables[0].find_all('tr')
#      31     #headers = get_headers(rows[0].find_all('th'))
# ---> 32     return build_country_list(rows[1:242])
#      33
#      34 def write_country_csv(path, country_list):
#
# <ipython-input-16-a39e0b8eff51> in build_country_list(rows)
#      21     country_list = []
#      22     for row in rows:
# ---> 23         country_list.append(get_row_values(row))
#      24     return country_list
#      25
#
# <ipython-input-16-a39e0b8eff51> in get_row_values(country)
#      14             'name': country.a.text.strip(),
#      15             'population': country.find('td', style='text-align:right').text.strip().replace(',',""),
# ---> 16             'percent_of_world': country.find('td', align='right').text[:-1]
#      17            }
#      18     return info
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %% [markdown]
# # Now that we have the .csv we scrape the demographics sites

# %%
def get_country_page(country_link):
    """
    function takes in a link to be appended to the base_url
    it retrievs the HTML code from the page
    
    function feturns the Beautiful Soup object 
    that contains all the html code from that page
    """
    country_url = 'https://en.wikipedia.org' + country_link
    response = requests.get(country_url)
    if response.status_code != 200: 
        print('Status code:', response.status_code)
        raise Exception('Failed to fetch web page ' + country_url)
    soup = BeautifulSoup(response.text)
    return soup

# next get every row that has a <th> tag as the first header
def get_row_data(table_rows):
    """
    function takes in a list of all the html rows of the table
    It then scrapes the data from each row of the table 
    returns a list of dictionaries of key value from each row
   
    If the row does not have a <td> tag then the row is a header break
    and we should stop scraping because rows below are not easily parsable
    """
    info = []
    for row in table_rows[1:]: #skip the first row because it is just the table title
        if (row.td == None):
            break  
        elif row.td.has_attr('class'): #if no 'class' this not a row we want
            if (row.td['class'][0] == 'infobox-data'): # list value for key returned so get [0]th element
                info.append({row.th.text: row.td.text}) # make dict item in list
    return info

def get_demographics(country_link):
    """
    function takes in the country link for Wiki
    returns a dictionary with the items from the info table
    returns None if there is no table or if not the table we want
    """
    soup = get_country_page(country_link) #retrieves the Beautiful soup Page
    table = soup.find('table', class_='infobox') #finds the first table in the page
    if table:
        if table.has_attr('style') and table.has_attr('class'):#and table['style']: #and table['style'] == 'width: 25em':
            table_rows = table.find_all('tr')
            info = get_row_data(table_rows)
            return info
    return

# %%
country_info = get_demographics('/wiki/Demographics_of_the_United_States')
country_info
# Out:
# [{'Population': '308,401,808\n(2010 Census[a]) (3rd)\n\n•\xa0Estimate\xa0329,484,123 (pre-2020 Census) (3rd)'},
#  {'Density': '86.16/sq\xa0mi (33.27/km2)'},
#  {'Growth rate': ' 0.72% (2020)[1]'},
#  {'Birth rate': '11.6 births/1,000 population (2020)[1]'},
#  {'Death rate': '8.9 deaths/1,000 population (2020)[1]'},
#  {'Life expectancy': '77.8 years (2020)[2]'},
#  {'\xa0•\xa0male': '75.1 years[2]'},
#  {'\xa0•\xa0female': '80.5 years[2]'},
#  {'Fertility rate': '1.706 children born/woman (2019)[3]'},
#  {'Net migration rate': '3 migrant(s)/1,000 population (2020)[1]'}]

# %%
# this removes the bullte of the Male/Female keys in the dictionaries
def parse_sex(country_info):
    for index, item in enumerate(country_info): 
        for key in item:
            if 'male' in key: # it could be male or female... 
                if 'female' in key:
                    country_info[index] = {'Female': item[key]} 
                else: 
                    country_info[index] = {'Male': item[key]}

# %%
parse_sex(country_info)
country_info
# Out:
# [{'Population': '308,401,808\n(2010 Census[a]) (3rd)\n\n•\xa0Estimate\xa0329,484,123 (pre-2020 Census) (3rd)'},
#  {'Density': '86.16/sq\xa0mi (33.27/km2)'},
#  {'Growth rate': ' 0.72% (2020)[1]'},
#  {'Birth rate': '11.6 births/1,000 population (2020)[1]'},
#  {'Death rate': '8.9 deaths/1,000 population (2020)[1]'},
#  {'Life expectancy': '77.8 years (2020)[2]'},
#  {'Male': '75.1 years[2]'},
#  {'Female': '80.5 years[2]'},
#  {'Fertility rate': '1.706 children born/woman (2019)[3]'},
#  {'Net migration rate': '3 migrant(s)/1,000 population (2020)[1]'}]

# %% [markdown]
# # now let us read the links in the .csv and cet all the country demos we can

# %%
country_df = pd.read_csv('country_list.csv')
country_df
# Out:
#     rank                                           link  \
# 0      1                    /wiki/Demographics_of_China
# 1      2                    /wiki/Demographics_of_India
# 2      3        /wiki/Demographics_of_the_United_States
# 3      4                /wiki/Demographics_of_Indonesia
# 4      5                 /wiki/Demographics_of_Pakistan
# ..   ...                                            ...
# 236    –                     /wiki/Demographics_of_Niue
# 237    –                  /wiki/Demographics_of_Tokelau
# 238  195             /wiki/Demographics_of_Vatican_City
# 239    –  /wiki/Demographics_of_Cocos_(Keeling)_Islands
# 240    –         /wiki/Demographics_of_Pitcairn_Islands
#
#                         name  population percent_of_world
# 0                      China  1407562280             17.9
# 1                      India  1375875687             17.5
# 2              United States   331520958             4.22
# 3                  Indonesia   271350000             3.45
# 4                   Pakistan   225200000             2.86
# ..                       ...         ...              ...
# 236                     Niue        1549                0
# 237                  Tokelau        1501                0
# 238             Vatican City         825                0
# 239  Cocos (Keeling) Islands         573                0
# 240         Pitcairn Islands          40                0
#
# [241 rows x 5 columns]

# %%
demo_links = country_df['link']

count = 0
for link in demo_links:
    temp = get_demographics(link)
    if temp == None:
        count += 1
    print(temp)
# Out:
# [{'Population': '1,427,647,786\n (2018 data) (1st)'}, {'Growth rate': ' 0.59% (2016 est.) (159th)'}, {'Birth rate': '11.673 births per 1,000 (2019 est.)'}, {'Death rate': '7.261 deaths per 1,000 (2019)'}, {'Life expectancy': '76.5 years (2019)'}, {'\xa0•\xa0male': '74.4 years (2018)'}, {'\xa0•\xa0female': '78.6 years (2018)'}, {'Fertility rate': '1.5 children per woman (2018)'}, {'Infant mortality rate': '9.595 deaths per 1000 live births (2019)'}]
# [{'Population': ' 1,390,885,000\n(April, 2021 est.)[1]'}, {'Density': '500 people per.sq.km (2011 est.)'}, {'Growth rate': '1.2% (2020 est.)[2]'}, {'Birth rate': '18.2 births/1,000 population (2020 est.)[2]'}, {'Death rate': '7.3 deaths/1,000 population (2020 est.)[2]'}, {'Life expectancy': '69.7 years (2020 est.)[2]'}, {'\xa0•\xa0male': '68.4 years (2020 est.)[2]'}, {'\xa0•\xa0female': '71.2 years (2020 est.)[2]'}, {'Fertility rate': '2.17 children born/woman (2017)[3]'}, {'Infant mortality rate': '29.94 deaths/1,000 live births (2018)[4]'}]
# [{'Population': '308,401,808\n(2010 Census[a]) (3rd)\n\n•\xa0Estimate\xa0329,484,123 (pre-2020 Census) (3rd)'}, {'Density': '86.16/sq\xa0mi (33.27/km2)'}, {'Growth rate': ' 0.72% (2020)[1]'}, {'Birth rate': '11.6 births/1,000 population (2020)[1]'}, {'Death rate': '8.9 deaths/1,000 population (2020)[1]'}, {'Life expectancy': '77.8 years (2020)[2]'}, {'\xa0•\xa0male': '75.1 years[2]'}, {'\xa0•\xa0female': '80.5 years[2]'}, {'Fertility rate': '1.706 children born/woman (2019)[3]'}, {'Net migration rate': '3 migrant(s)/1,000 population (2020)[1]'}]
# [{'Sovereign state': 'Australia'}, {'Annexed by the United Kingdom': '1857'}, {'Transferred from Singaporeto Australia': '23 November 1955'}, {'Capital': 'West Island12°11′13″S 96°49′42″E\ufeff / \ufeff12.18694°S 96.82833°E\ufeff / -12.18694; 96.82833'}, {'Largest village': 'Bantam (Home Island)'}, {'Official languages': 'None'}, {'Spoken languages': 'MalayEnglish[a]'}, {'Government': 'Directly administered dependency'}, {'•\xa0Monarch ': 'Elizabeth II'}, {'•\xa0Governor-General ': 'David Hurley'}, {'•\xa0Administrator ': 'Natasha Griggs'}, {'•\xa0Shire President ': 'Seri Wati Iku'}]
# None

# %% [markdown]
# # now let us read this file out to a csv and then back in with Pandas
# * oh question -- can I somehow just convert the list to a pandas dataframe?
# * is there a way to put things into a jupyter notebook that are searchable
# * is it possible to but local links in a jupyter notebook, for instance I want to build a TOC with links to those sections of the notebook
# * Is it standard to extract the key (or class) names from the data or to opt for writing out a more friendly version without spaces or special characters?

# %%
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'from bs4 import BeautifulSoup\nimport pandas as pd\nimport requests',
#   '# now lets get all of the countries from the table\n# ths is from the table at https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population\n\ndef get_headers(table_header_row):\n    cols = []\n    for col in table_header_row:\n        cols.append(col.text.strip()) \n    return cols[:4] # we dont want the date or the source\n\ndef get_row_values(country): \n    info = {\n            \'rank\': country.th.text.strip(),\n            \'link\': country.a[\'href\'],\n            \'name\': country.a.text.strip(),\n            \'population\': country.find(\'td\', style=\'text-align:right\').text.strip().replace(\',\',""),\n            \'percent_of_world\': country.find(\'td\', align=\'right\').text[:-1]\n           }\n    return info\n\ndef build_country_list(rows):\n    country_list = []\n    for row in rows:\n        country_list.append(get_row_values(row))\n    return country_list\n\ndef scrape_wiki_table():\n    world_countries_url = \'https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population\'\n    soup = BeautifulSoup(requests.get(world_countries_url).text)\n    tables = soup.find_all(\'table\', class_=\'wikitable sortable plainrowheaders\')\n    rows = tables[0].find_all(\'tr\')\n    #headers = get_headers(rows[0].find_all(\'th\'))\n    return build_country_list(rows[1:242])\n\ndef write_country_csv(path, country_list):\n    df = pd.DataFrame(country_list)\n    df.to_csv(path, index=False, header=True)',
#   "country_list = scrape_wiki_table()\nwrite_country_csv('country_list.csv', country_list)",
#   'def get_country_page(country_link):\n    """\n    function takes in a link to be appended to the base_url\n    it retrievs the HTML code from the page\n    \n    function feturns the Beautiful Soup object \n    that contains all the html code from that page\n    """\n    country_url = \'https://en.wikipedia.org\' + country_link\n    response = requests.get(country_url)\n    if response.status_code != 200: \n        print(\'Status code:\', response.status_code)\n        raise Exception(\'Failed to fetch web page \' + country_url)\n    soup = BeautifulSoup(response.text)\n    return soup\n\n# next get every row that has a <th> tag as the first header\ndef get_row_data(table_rows):\n    """\n    function takes in a list of all the html rows of the table\n    It then scrapes the data from each row of the table \n    returns a list of dictionaries of key value from each row\n   \n    If the row does not have a <td> tag then the row is a header break\n    and we should stop scraping because rows below are not easily parsable\n    """\n    info = []\n    for row in table_rows[1:]: #skip the first row because it is just the table title\n        if (row.td == None):\n            break  \n        elif row.td.has_attr(\'class\'): #if no \'class\' this not a row we want\n            if (row.td[\'class\'][0] == \'infobox-data\'): # list value for key returned so get [0]th element\n                info.append({row.th.text: row.td.text}) # make dict item in list\n    return info\n\ndef get_demographics(country_link):\n    """\n    function takes in the country link for Wiki\n    returns a dictionary with the items from the info table\n    returns None if there is no table or if not the table we want\n    """\n    soup = get_country_page(country_link) #retrieves the Beautiful soup Page\n    table = soup.find(\'table\', class_=\'infobox\') #finds the first table in the page\n    if table:\n        if table.has_attr(\'style\') and table.has_attr(\'class\'):#and table[\'style\']: #and table[\'style\'] == \'width: 25em\':\n            table_rows = table.find_all(\'tr\')\n            info = get_row_data(table_rows)\n            return info\n    return',
#   "country_info = get_demographics('/wiki/Demographics_of_the_United_States')\ncountry_info",
#   "# this removes the bullte of the Male/Female keys in the dictionaries\ndef parse_sex(country_info):\n    for index, item in enumerate(country_info): \n        for key in item:\n            if 'male' in key: # it could be male or female... \n                if 'female' in key:\n                    country_info[index] = {'Female': item[key]} \n                else: \n                    country_info[index] = {'Male': item[key]}",
#   'parse_sex(country_info)\ncountry_info',
#   "country_df = pd.read_csv('country_list.csv')\ncountry_df",
#   "demo_links = country_df['link']\n\ncount = 0\nfor link in demo_links:\n    temp = get_demographics(link)\n    if temp == None:\n        count += 1\n    print(temp)\n    \n    ",
#   'None in temp',
#   'None in temp[0]',
#   'temp[0]',
#   'temp[1]',
#   'temp',
#   'locals()'],
#  '_oh': {5: [{'Population': '308,401,808\n(2010 Census[a]) (3rd)\n\n•\xa0Estimate\xa0329,484,123 (pre-2020 Census) (3rd)'},
#    {'Density': '86.16/sq\xa0mi (33.27/km2)'},
#    {'Growth rate': ' 0.72% (2020)[1]'},
#    {'Birth rate': '11.6 births/1,000 population (2020)[1]'},
#    {'Death rate': '8.9 deaths/1,000 population (2020)[1]'},
#    {'Life expectancy': '77.8 years (2020)[2]'},
#    {'Male': '75.1 years[2]'},
#    {'Female': '80.5 years[2]'},
#    {'Fertility rate': '1.706 children born/woman (2019)[3]'},
#    {'Net migration rate': '3 migrant(s)/1,000 population (2020)[1]'}],
#   7: [{'Population': '308,401,808\n(2010 Census[a]) (3rd)\n\n•\xa0Estimate\xa0329,484,123 (pre-2020 Census) (3rd)'},
#    {'Density': '86.16/sq\xa0mi (33.27/km2)'},
#    {'Growth rate': ' 0.72% (2020)[1]'},
#    {'Birth rate': '11.6 births/1,000 population (2020)[1]'},
#    {'Death rate': '8.9 deaths/1,000 population (2020)[1]'},
#    {'Life expectancy': '77.8 years (2020)[2]'},
#    {'Male': '75.1 years[2]'},
#    {'Female': '80.5 years[2]'},
#    {'Fertility rate': '1.706 children born/woman (2019)[3]'},
#    {'Net migration rate': '3 migrant(s)/1,000 population (2020)[1]'}],
#   8:     rank                                           link  \
#   0      1                    /wiki/Demographics_of_China
#   1      2                    /wiki/Demographics_of_India
#   2      3        /wiki/Demographics_of_the_United_States
#   3      4                /wiki/Demographics_of_Indonesia
#   4      5                 /wiki/Demographics_of_Pakistan
#   ..   ...                                            ...
#   236    –                     /wiki/Demographics_of_Niue
#   237    –                  /wiki/Demographics_of_Tokelau
#   238  195             /wiki/Demographics_of_Vatican_City
#   239    –  /wiki/Demographics_of_Cocos_(Keeling)_Islands
#   240    –         /wiki/Demographics_of_Pitcairn_Islands
#
#                           name  population percent_of_world
#   0                      China  1407562280             17.9
#   1                      India  1375875687             17.5
#   2              United States   331520958             4.22
#   3                  Indonesia   271350000             3.45
#   4                   Pakistan   225200000             2.86
#   ..                       ...         ...              ...
#   236                     Niue        1549                0
#   237                  Tokelau        1501                0
#   238             Vatican City         825                0
#   239  Cocos (Keeling) Islands         573                0
#   240         Pitcairn Islands          40                0
#
#   [241 rows x 5 columns]},
#  '_dh': ['C:\\Users\\Sam\\Jovian\\Projects\\Web_Scraping_Project'],
#  'In': ['',
#   'from bs4 import BeautifulSoup\nimport pandas as pd\nimport requests',
#   '# now lets get all of the countries from the table\n# ths is from the table at https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population\n\ndef get_headers(table_header_row):\n    cols = []\n    for col in table_header_row:\n        cols.append(col.text.strip()) \n    return cols[:4] # we dont want the date or the source\n\ndef get_row_values(country): \n    info = {\n            \'rank\': country.th.text.strip(),\n            \'link\': country.a[\'href\'],\n            \'name\': country.a.text.strip(),\n            \'population\': country.find(\'td\', style=\'text-align:right\').text.strip().replace(\',\',""),\n            \'percent_of_world\': country.find(\'td\', align=\'right\').text[:-1]\n           }\n    return info\n\ndef build_country_list(rows):\n    country_list = []\n    for row in rows:\n        country_list.append(get_row_values(row))\n    return country_list\n\ndef scrape_wiki_table():\n    world_countries_url = \'https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population\'\n    soup = BeautifulSoup(requests.get(world_countries_url).text)\n    tables = soup.find_all(\'table\', class_=\'wikitable sortable plainrowheaders\')\n    rows = tables[0].find_all(\'tr\')\n    #headers = get_headers(rows[0].find_all(\'th\'))\n    return build_country_list(rows[1:242])\n\ndef write_country_csv(path, country_list):\n    df = pd.DataFrame(country_list)\n    df.to_csv(path, index=False, header=True)',
#   "country_list = scrape_wiki_table()\nwrite_country_csv('country_list.csv', country_list)",
#   'def get_country_page(country_link):\n    """\n    function takes in a link to be appended to the base_url\n    it retrievs the HTML code from the page\n    \n    function feturns the Beautiful Soup object \n    that contains all the html code from that page\n    """\n    country_url = \'https://en.wikipedia.org\' + country_link\n    response = requests.get(country_url)\n    if response.status_code != 200: \n        print(\'Status code:\', response.status_code)\n        raise Exception(\'Failed to fetch web page \' + country_url)\n    soup = BeautifulSoup(response.text)\n    return soup\n\n# next get every row that has a <th> tag as the first header\ndef get_row_data(table_rows):\n    """\n    function takes in a list of all the html rows of the table\n    It then scrapes the data from each row of the table \n    returns a list of dictionaries of key value from each row\n   \n    If the row does not have a <td> tag then the row is a header break\n    and we should stop scraping because rows below are not easily parsable\n    """\n    info = []\n    for row in table_rows[1:]: #skip the first row because it is just the table title\n        if (row.td == None):\n            break  \n        elif row.td.has_attr(\'class\'): #if no \'class\' this not a row we want\n            if (row.td[\'class\'][0] == \'infobox-data\'): # list value for key returned so get [0]th element\n                info.append({row.th.text: row.td.text}) # make dict item in list\n    return info\n\ndef get_demographics(country_link):\n    """\n    function takes in the country link for Wiki\n    returns a dictionary with the items from the info table\n    returns None if there is no table or if not the table we want\n    """\n    soup = get_country_page(country_link) #retrieves the Beautiful soup Page\n    table = soup.find(\'table\', class_=\'infobox\') #finds the first table in the page\n    if table:\n        if table.has_attr(\'style\') and table.has_attr(\'class\'):#and table[\'style\']: #and table[\'style\'] == \'width: 25em\':\n            table_rows = table.find_all(\'tr\')\n            info = get_row_data(table_rows)\n            return info\n    return',
#   "country_info = get_demographics('/wiki/Demographics_of_the_United_States')\ncountry_info",
#   "# this removes the bullte of the Male/Female keys in the dictionaries\ndef parse_sex(country_info):\n    for index, item in enumerate(country_info): \n        for key in item:\n            if 'male' in key: # it could be male or female... \n                if 'female' in key:\n                    country_info[index] = {'Female': item[key]} \n                else: \n                    country_info[index] = {'Male': item[key]}",
#   'parse_sex(country_info)\ncountry_info',
#   "country_df = pd.read_csv('country_list.csv')\ncountry_df",
#   "demo_links = country_df['link']\n\ncount = 0\nfor link in demo_links:\n    temp = get_demographics(link)\n    if temp == None:\n        count += 1\n    print(temp)\n    \n    ",
#   'None in temp',
#   'None in temp[0]',
#   'temp[0]',
#   'temp[1]',
#   'temp',
#   'locals()'],
#  'Out': {5: [{'Population': '308,401,808\n(2010 Census[a]) (3rd)\n\n•\xa0Estimate\xa0329,484,123 (pre-2020 Census) (3rd)'},
#    {'Density': '86.16/sq\xa0mi (33.27/km2)'},
#    {'Growth rate': ' 0.72% (2020)[1]'},
#    {'Birth rate': '11.6 births/1,000 population (2020)[1]'},
#    {'Death rate': '8.9 deaths/1,000 population (2020)[1]'},
#    {'Life expectancy': '77.8 years (2020)[2]'},
#    {'Male': '75.1 years[2]'},
#    {'Female': '80.5 years[2]'},
#    {'Fertility rate': '1.706 children born/woman (2019)[3]'},
#    {'Net migration rate': '3 migrant(s)/1,000 population (2020)[1]'}],
#   7: [{'Population': '308,401,808\n(2010 Census[a]) (3rd)\n\n•\xa0Estimate\xa0329,484,123 (pre-2020 Census) (3rd)'},
#    {'Density': '86.16/sq\xa0mi (33.27/km2)'},
#    {'Growth rate': ' 0.72% (2020)[1]'},
#    {'Birth rate': '11.6 births/1,000 population (2020)[1]'},
#    {'Death rate': '8.9 deaths/1,000 population (2020)[1]'},
#    {'Life expectancy': '77.8 years (2020)[2]'},
#    {'Male': '75.1 years[2]'},
#    {'Female': '80.5 years[2]'},
#    {'Fertility rate': '1.706 children born/woman (2019)[3]'},
#    {'Net migration rate': '3 migrant(s)/1,000 population (2020)[1]'}],
#   8:     rank                                           link  \
#   0      1                    /wiki/Demographics_of_China
#   1      2                    /wiki/Demographics_of_India
#   2      3        /wiki/Demographics_of_the_United_States
#   3      4                /wiki/Demographics_of_Indonesia
#   4      5                 /wiki/Demographics_of_Pakistan
#   ..   ...                                            ...
#   236    –                     /wiki/Demographics_of_Niue
#   237    –                  /wiki/Demographics_of_Tokelau
#   238  195             /wiki/Demographics_of_Vatican_City
#   239    –  /wiki/Demographics_of_Cocos_(Keeling)_Islands
#   240    –         /wiki/Demographics_of_Pitcairn_Islands
#
#                           name  population percent_of_world
#   0                      China  1407562280             17.9
#   1                      India  1375875687             17.5
#   2              United States   331520958             4.22
#   3                  Indonesia   271350000             3.45
#   4                   Pakistan   225200000             2.86
#   ..                       ...         ...              ...
#   236                     Niue        1549                0
#   237                  Tokelau        1501                0
#   238             Vatican City         825                0
#   239  Cocos (Keeling) Islands         573                0
#   240         Pitcairn Islands          40                0
#
#   [241 rows x 5 columns]},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000207B367D308>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x207b36a1f48>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x207b36a1f48>,
#  '_': 'read',
#  '__': [{'Population': '308,401,808\n(2010 Census[a]) (3rd)\n\n•\xa0Estimate\xa0329,484,123 (pre-2020 Census) (3rd)'},
#   {'Density': '86.16/sq\xa0mi (33.27/km2)'},
#   {'Growth rate': ' 0.72% (2020)[1]'},
#   {'Birth rate': '11.6 births/1,000 population (2020)[1]'},
#   {'Death rate': '8.9 deaths/1,000 population (2020)[1]'},
#   {'Life expectancy': '77.8 years (2020)[2]'},
#   {'Male': '75.1 years[2]'},
#   {'Female': '80.5 years[2]'},
#   {'Fertility rate': '1.706 children born/woman (2019)[3]'},
#   {'Net migration rate': '3 migrant(s)/1,000 population (2020)[1]'}],
#  '___': [{'Population': '308,401,808\n(2010 Census[a]) (3rd)\n\n•\xa0Estimate\xa0329,484,123 (pre-2020 Census) (3rd)'},
#   {'Density': '86.16/sq\xa0mi (33.27/km2)'},
#   {'Growth rate': ' 0.72% (2020)[1]'},
#   {'Birth rate': '11.6 births/1,000 population (2020)[1]'},
#   {'Death rate': '8.9 deaths/1,000 population (2020)[1]'},
#   {'Life expectancy': '77.8 years (2020)[2]'},
#   {'Male': '75.1 years[2]'},
#   {'Female': '80.5 years[2]'},
#   {'Fertility rate': '1.706 children born/woman (2019)[3]'},
#   {'Net migration rate': '3 migrant(s)/1,000 population (2020)[1]'}],
#  'get_notebook_slug': <function jovian.utils.rcfile.get_notebook_slug(filename, cache_result=True)>,
#  'jovian': <module 'jovian' from 'C:\\Users\\Sam\\anaconda3\\lib\\site-packages\\jovian\\__init__.py'>,
#  '_i': 'temp',
#  '_ii': 'temp[1]',
#  '_iii': 'temp[0]',
#  '_i1': 'from bs4 import BeautifulSoup\nimport pandas as pd\nimport requests',
#  'BeautifulSoup': bs4.BeautifulSoup,
#  'pd': <module 'pandas' from 'C:\\Users\\Sam\\anaconda3\\lib\\site-packages\\pandas\\__init__.py'>,
#  'requests': <module 'requests' from 'C:\\Users\\Sam\\anaconda3\\lib\\site-packages\\requests\\__init__.py'>,
#  '_i2': '# now lets get all of the countries from the table\n# ths is from the table at https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population\n\ndef get_headers(table_header_row):\n    cols = []\n    for col in table_header_row:\n        cols.append(col.text.strip()) \n    return cols[:4] # we dont want the date or the source\n\ndef get_row_values(country): \n    info = {\n            \'rank\': country.th.text.strip(),\n            \'link\': country.a[\'href\'],\n            \'name\': country.a.text.strip(),\n            \'population\': country.find(\'td\', style=\'text-align:right\').text.strip().replace(\',\',""),\n            \'percent_of_world\': country.find(\'td\', align=\'right\').text[:-1]\n           }\n    return info\n\ndef build_country_list(rows):\n    country_list = []\n    for row in rows:\n        country_list.append(get_row_values(row))\n    return country_list\n\ndef scrape_wiki_table():\n    world_countries_url = \'https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population\'\n    soup = BeautifulSoup(requests.get(world_countries_url).text)\n    tables = soup.find_all(\'table\', class_=\'wikitable sortable plainrowheaders\')\n    rows = tables[0].find_all(\'tr\')\n    #headers = get_headers(rows[0].find_all(\'th\'))\n    return build_country_list(rows[1:242])\n\ndef write_country_csv(path, country_list):\n    df = pd.DataFrame(country_list)\n    df.to_csv(path, index=False, header=True)',
#  'get_headers': <function __main__.get_headers(table_header_row)>,
#  'get_row_values': <function __main__.get_row_values(country)>,
#  'build_country_list': <function __main__.build_country_list(rows)>,
#  'scrape_wiki_table': <function __main__.scrape_wiki_table()>,
#  'write_country_csv': <function __main__.write_country_csv(path, country_list)>,
#  '_i3': "country_list = scrape_wiki_table()\nwrite_country_csv('country_list.csv', country_list)",
#  'country_list': [{'rank': '1',
#    'link': '/wiki/Demographics_of_China',
#    'name': 'China',
#    'population': '1407562280',
#    'percent_of_world': '17.9'},
#   {'rank': '2',
#    'link': '/wiki/Demographics_of_India',
#    'name': 'India',
#    'population': '1375875687',
#    'percent_of_world': '17.5'},
#   {'rank': '3',
#    'link': '/wiki/Demographics_of_the_United_States',
#    'name': 'United States',
#    'population': '331520958',
#    'percent_of_world': '4.22'},
#   {'rank': '4',
#    'link': '/wiki/Demographics_of_Indonesia',
#    'name': 'Indonesia',
#    'population': '271350000',
#    'percent_of_world': '3.45'},
#   {'rank': '5',
#    'link': '/wiki/Demographics_of_Pakistan',
#    'name': 'Pakistan',
#    'population': '225200000',
#    'percent_of_world': '2.86'},
#   {'rank': '6',
#    'link': '/wiki/Demographics_of_Brazil',
#    'name': 'Brazil',
#    'population': '213018066',
#    'percent_of_world': '2.71'},
#   {'rank': '7',
#    'link': '/wiki/Demographics_of_Nigeria',
#    'name': 'Nigeria',
#    'population': '211401000',
#    'percent_of_world': '2.69'},
#   {'rank': '8',
#    'link': '/wiki/Demographics_of_Bangladesh',
#    'name': 'Bangladesh',
#    'population': '170515426',
#    'percent_of_world': '2.17'},
#   {'rank': '9',
#    'link': '/wiki/Demographics_of_Russia',
#    'name': 'Russia',
#    'population': '146238185',
#    'percent_of_world': '1.86'},
#   {'rank': '10',
#    'link': '/wiki/Demographics_of_Mexico',
#    'name': 'Mexico',
#    'population': '126014024',
#    'percent_of_world': '1.60'},
#   {'rank': '11',
#    'link': '/wiki/Demographics_of_Japan',
#    'name': 'Japan',
#    'population': '125480000',
#    'percent_of_world': '1.60'},
#   {'rank': '12',
#    'link': '/wiki/Demographics_of_Ethiopia',
#    'name': 'Ethiopia',
#    'population': '117876000',
#    'percent_of_world': '1.50'},
#   {'rank': '13',
#    'link': '/wiki/Demographics_of_Philippines',
#    'name': 'Philippines',
#    'population': '110106177',
#    'percent_of_world': '1.40'},
#   {'rank': '14',
#    'link': '/wiki/Demographics_of_Egypt',
#    'name': 'Egypt',
#    'population': '101759497',
#    'percent_of_world': '1.29'},
#   {'rank': '15',
#    'link': '/wiki/Demographics_of_Vietnam',
#    'name': 'Vietnam',
#    'population': '97580000',
#    'percent_of_world': '1.24'},
#   {'rank': '16',
#    'link': '/wiki/Demographics_of_Democratic_Republic_of_the_Congo',
#    'name': 'DR Congo',
#    'population': '92378000',
#    'percent_of_world': '1.18'},
#   {'rank': '17',
#    'link': '/wiki/Demographics_of_Iran',
#    'name': 'Iran',
#    'population': '84370508',
#    'percent_of_world': '1.07'},
#   {'rank': '18',
#    'link': '/wiki/Demographics_of_Turkey',
#    'name': 'Turkey',
#    'population': '83614362',
#    'percent_of_world': '1.06'},
#   {'rank': '19',
#    'link': '/wiki/Demographics_of_Germany',
#    'name': 'Germany',
#    'population': '83190556',
#    'percent_of_world': '1.06'},
#   {'rank': '20',
#    'link': '/wiki/Demographics_of_France',
#    'name': 'France',
#    'population': '67399000',
#    'percent_of_world': '0.857'},
#   {'rank': '21',
#    'link': '/wiki/Demographics_of_United_Kingdom',
#    'name': 'United Kingdom',
#    'population': '66796807',
#    'percent_of_world': '0.850'},
#   {'rank': '22',
#    'link': '/wiki/Demographics_of_Thailand',
#    'name': 'Thailand',
#    'population': '66636242',
#    'percent_of_world': '0.848'},
#   {'rank': '23',
#    'link': '/wiki/Demographics_of_South_Africa',
#    'name': 'South Africa',
#    'population': '59622350',
#    'percent_of_world': '0.758'},
#   {'rank': '24',
#    'link': '/wiki/Demographics_of_Tanzania',
#    'name': 'Tanzania',
#    'population': '59441988',
#    'percent_of_world': '0.756'},
#   {'rank': '25',
#    'link': '/wiki/Demographics_of_Italy',
#    'name': 'Italy',
#    'population': '59257566',
#    'percent_of_world': '0.754'},
#   {'rank': '26',
#    'link': '/wiki/Demographics_of_Myanmar',
#    'name': 'Myanmar',
#    'population': '55294979',
#    'percent_of_world': '0.703'},
#   {'rank': '27',
#    'link': '/wiki/Demographics_of_South_Korea',
#    'name': 'South Korea',
#    'population': '51705905',
#    'percent_of_world': '0.658'},
#   {'rank': '28',
#    'link': '/wiki/Demographics_of_Colombia',
#    'name': 'Colombia',
#    'population': '51049498',
#    'percent_of_world': '0.649'},
#   {'rank': '29',
#    'link': '/wiki/Demographics_of_Kenya',
#    'name': 'Kenya',
#    'population': '47564296',
#    'percent_of_world': '0.605'},
#   {'rank': '30',
#    'link': '/wiki/Demographics_of_Spain',
#    'name': 'Spain',
#    'population': '47351567',
#    'percent_of_world': '0.602'},
#   {'rank': '31',
#    'link': '/wiki/Demographics_of_Argentina',
#    'name': 'Argentina',
#    'population': '45808747',
#    'percent_of_world': '0.583'},
#   {'rank': '32',
#    'link': '/wiki/Demographics_of_Algeria',
#    'name': 'Algeria',
#    'population': '44700000',
#    'percent_of_world': '0.569'},
#   {'rank': '33',
#    'link': '/wiki/Demographics_of_Sudan',
#    'name': 'Sudan',
#    'population': '43397075',
#    'percent_of_world': '0.552'},
#   {'rank': '34',
#    'link': '/wiki/Demographics_of_Uganda',
#    'name': 'Uganda',
#    'population': '42885900',
#    'percent_of_world': '0.545'},
#   {'rank': '35',
#    'link': '/wiki/Demographics_of_Ukraine',
#    'name': 'Ukraine',
#    'population': '41554836',
#    'percent_of_world': '0.529'},
#   {'rank': '36',
#    'link': '/wiki/Demographics_of_Iraq',
#    'name': 'Iraq',
#    'population': '41190700',
#    'percent_of_world': '0.524'},
#   {'rank': '37',
#    'link': '/wiki/Population_of_Canada',
#    'name': 'Canada',
#    'population': '38424749',
#    'percent_of_world': '0.489'},
#   {'rank': '38',
#    'link': '/wiki/Demographics_of_Poland',
#    'name': 'Poland',
#    'population': '38244000',
#    'percent_of_world': '0.486'},
#   {'rank': '39',
#    'link': '/wiki/Demographics_of_Morocco',
#    'name': 'Morocco',
#    'population': '36224101',
#    'percent_of_world': '0.461'},
#   {'rank': '40',
#    'link': '/wiki/Demographics_of_Uzbekistan',
#    'name': 'Uzbekistan',
#    'population': '34812056',
#    'percent_of_world': '0.443'},
#   {'rank': '41',
#    'link': '/wiki/Demographics_of_Saudi_Arabia',
#    'name': 'Saudi Arabia',
#    'population': '34218169',
#    'percent_of_world': '0.435'},
#   {'rank': '42',
#    'link': '/wiki/Demographics_of_Peru',
#    'name': 'Peru',
#    'population': '33035304',
#    'percent_of_world': '0.420'},
#   {'rank': '43',
#    'link': '/wiki/Demographics_of_Afghanistan',
#    'name': 'Afghanistan',
#    'population': '32890171',
#    'percent_of_world': '0.418'},
#   {'rank': '44',
#    'link': '/wiki/Demographics_of_Malaysia',
#    'name': 'Malaysia',
#    'population': '32764970',
#    'percent_of_world': '0.417'},
#   {'rank': '45',
#    'link': '/wiki/Demographics_of_Angola',
#    'name': 'Angola',
#    'population': '32097671',
#    'percent_of_world': '0.408'},
#   {'rank': '46',
#    'link': '/wiki/Demographics_of_Ghana',
#    'name': 'Ghana',
#    'population': '30955202',
#    'percent_of_world': '0.394'},
#   {'rank': '47',
#    'link': '/wiki/Demographics_of_Mozambique',
#    'name': 'Mozambique',
#    'population': '30832244',
#    'percent_of_world': '0.392'},
#   {'rank': '48',
#    'link': '/wiki/Demographics_of_Yemen',
#    'name': 'Yemen',
#    'population': '30491000',
#    'percent_of_world': '0.388'},
#   {'rank': '49',
#    'link': '/wiki/Demographics_of_Nepal',
#    'name': 'Nepal',
#    'population': '30378055',
#    'percent_of_world': '0.386'},
#   {'rank': '50',
#    'link': '/wiki/Demographics_of_Venezuela',
#    'name': 'Venezuela',
#    'population': '28705000',
#    'percent_of_world': '0.365'},
#   {'rank': '51',
#    'link': '/wiki/Demographics_of_Ivory_Coast',
#    'name': 'Ivory Coast',
#    'population': '27087732',
#    'percent_of_world': '0.345'},
#   {'rank': '52',
#    'link': '/wiki/Demographics_of_Madagascar',
#    'name': 'Madagascar',
#    'population': '26923353',
#    'percent_of_world': '0.342'},
#   {'rank': '53',
#    'link': '/wiki/Demographics_of_Australia',
#    'name': 'Australia',
#    'population': '25782518',
#    'percent_of_world': '0.328'},
#   {'rank': '54',
#    'link': '/wiki/Demographics_of_North_Korea',
#    'name': 'North Korea',
#    'population': '25660000',
#    'percent_of_world': '0.326'},
#   {'rank': '55',
#    'link': '/wiki/Demographics_of_Cameroon',
#    'name': 'Cameroon',
#    'population': '24348251',
#    'percent_of_world': '0.310'},
#   {'rank': '56',
#    'link': '/wiki/Demographics_of_Niger',
#    'name': 'Niger',
#    'population': '24112753',
#    'percent_of_world': '0.307'},
#   {'rank': '–',
#    'link': '/wiki/Demographics_of_Taiwan',
#    'name': 'Taiwan',
#    'population': '23525623',
#    'percent_of_world': '0.299%'},
#   {'rank': '57',
#    'link': '/wiki/Demographics_of_Sri_Lanka',
#    'name': 'Sri Lanka',
#    'population': '21919000',
#    'percent_of_world': '0.279'},
#   {'rank': '58',
#    'link': '/wiki/Demographics_of_Burkina_Faso',
#    'name': 'Burkina Faso',
#    'population': '21510181',
#    'percent_of_world': '0.274'},
#   {'rank': '59',
#    'link': '/wiki/Demographics_of_Mali',
#    'name': 'Mali',
#    'population': '20856000',
#    'percent_of_world': '0.265'},
#   {'rank': '60',
#    'link': '/wiki/Demographics_of_Chile',
#    'name': 'Chile',
#    'population': '19678363',
#    'percent_of_world': '0.250'},
#   {'rank': '61',
#    'link': '/wiki/Demographics_of_Romania',
#    'name': 'Romania',
#    'population': '19317984',
#    'percent_of_world': '0.246'},
#   {'rank': '62',
#    'link': '/wiki/Demographics_of_Kazakhstan',
#    'name': 'Kazakhstan',
#    'population': '18909168',
#    'percent_of_world': '0.241'},
#   {'rank': '63',
#    'link': '/wiki/Demographics_of_Malawi',
#    'name': 'Malawi',
#    'population': '18898441',
#    'percent_of_world': '0.240'},
#   {'rank': '64',
#    'link': '/wiki/Demographics_of_Zambia',
#    'name': 'Zambia',
#    'population': '18400556',
#    'percent_of_world': '0.234'},
#   {'rank': '65',
#    'link': '/wiki/Demographics_of_Syria',
#    'name': 'Syria',
#    'population': '18276000',
#    'percent_of_world': '0.232'},
#   {'rank': '66',
#    'link': '/wiki/Demographics_of_Ecuador',
#    'name': 'Ecuador',
#    'population': '17714280',
#    'percent_of_world': '0.225'},
#   {'rank': '67',
#    'link': '/wiki/Demographics_of_Netherlands',
#    'name': 'Netherlands',
#    'population': '17584381',
#    'percent_of_world': '0.224'},
#   {'rank': '68',
#    'link': '/wiki/Demographics_of_Senegal',
#    'name': 'Senegal',
#    'population': '17223497',
#    'percent_of_world': '0.219'},
#   {'rank': '69',
#    'link': '/wiki/Demographics_of_Guatemala',
#    'name': 'Guatemala',
#    'population': '17109746',
#    'percent_of_world': '0.218'},
#   {'rank': '70',
#    'link': '/wiki/Demographics_of_Chad',
#    'name': 'Chad',
#    'population': '16818391',
#    'percent_of_world': '0.214'},
#   {'rank': '71',
#    'link': '/wiki/Demographics_of_Somalia',
#    'name': 'Somalia',
#    'population': '16360000',
#    'percent_of_world': '0.208'},
#   {'rank': '72',
#    'link': '/wiki/Demographics_of_Zimbabwe',
#    'name': 'Zimbabwe',
#    'population': '15790716',
#    'percent_of_world': '0.201'},
#   {'rank': '73',
#    'link': '/wiki/Demographics_of_Cambodia',
#    'name': 'Cambodia',
#    'population': '15552211',
#    'percent_of_world': '0.198'},
#   {'rank': '74',
#    'link': '/wiki/Demographics_of_South_Sudan',
#    'name': 'South Sudan',
#    'population': '13249924',
#    'percent_of_world': '0.169'},
#   {'rank': '75',
#    'link': '/wiki/Demographics_of_Rwanda',
#    'name': 'Rwanda',
#    'population': '12955768',
#    'percent_of_world': '0.165'},
#   {'rank': '76',
#    'link': '/wiki/Demographics_of_Guinea',
#    'name': 'Guinea',
#    'population': '12907395',
#    'percent_of_world': '0.164'},
#   {'rank': '77',
#    'link': '/wiki/Demographics_of_Burundi',
#    'name': 'Burundi',
#    'population': '12574571',
#    'percent_of_world': '0.160'},
#   {'rank': '78',
#    'link': '/wiki/Demographics_of_Benin',
#    'name': 'Benin',
#    'population': '12506347',
#    'percent_of_world': '0.159'},
#   {'rank': '79',
#    'link': '/wiki/Demographics_of_Bolivia',
#    'name': 'Bolivia',
#    'population': '11797257',
#    'percent_of_world': '0.150'},
#   {'rank': '80',
#    'link': '/wiki/Demographics_of_Haiti',
#    'name': 'Haiti',
#    'population': '11743017',
#    'percent_of_world': '0.149'},
#   {'rank': '81',
#    'link': '/wiki/Demographics_of_Tunisia',
#    'name': 'Tunisia',
#    'population': '11708370',
#    'percent_of_world': '0.149'},
#   {'rank': '82',
#    'link': '/wiki/Demographics_of_Belgium',
#    'name': 'Belgium',
#    'population': '11556297',
#    'percent_of_world': '0.147'},
#   {'rank': '83',
#    'link': '/wiki/Demographics_of_Cuba',
#    'name': 'Cuba',
#    'population': '11193470',
#    'percent_of_world': '0.142'},
#   {'rank': '84',
#    'link': '/wiki/Demographics_of_Jordan',
#    'name': 'Jordan',
#    'population': '10925240',
#    'percent_of_world': '0.139'},
#   {'rank': '85',
#    'link': '/wiki/Demographics_of_Greece',
#    'name': 'Greece',
#    'population': '10718565',
#    'percent_of_world': '0.136'},
#   {'rank': '86',
#    'link': '/wiki/Demographics_of_Czech_Republic',
#    'name': 'Czech Republic',
#    'population': '10701777',
#    'percent_of_world': '0.136'},
#   {'rank': '87',
#    'link': '/wiki/Demographics_of_Dominican_Republic',
#    'name': 'Dominican Republic',
#    'population': '10535535',
#    'percent_of_world': '0.134'},
#   {'rank': '88',
#    'link': '/wiki/Demographics_of_Sweden',
#    'name': 'Sweden',
#    'population': '10385347',
#    'percent_of_world': '0.132'},
#   {'rank': '89',
#    'link': '/wiki/Demographics_of_Portugal',
#    'name': 'Portugal',
#    'population': '10295909',
#    'percent_of_world': '0.131'},
#   {'rank': '90',
#    'link': '/wiki/Demographics_of_Azerbaijan',
#    'name': 'Azerbaijan',
#    'population': '10122148',
#    'percent_of_world': '0.129'},
#   {'rank': '91',
#    'link': '/wiki/Demographics_of_Hungary',
#    'name': 'Hungary',
#    'population': '9730000',
#    'percent_of_world': '0.124'},
#   {'rank': '92',
#    'link': '/wiki/Demographics_of_United_Arab_Emirates',
#    'name': 'United Arab Emirates',
#    'population': '9503738',
#    'percent_of_world': '0.121'},
#   {'rank': '93',
#    'link': '/wiki/Demographics_of_Honduras',
#    'name': 'Honduras',
#    'population': '9450711',
#    'percent_of_world': '0.120'},
#   {'rank': '94',
#    'link': '/wiki/Demographics_of_Belarus',
#    'name': 'Belarus',
#    'population': '9349645',
#    'percent_of_world': '0.119'},
#   {'rank': '95',
#    'link': '/wiki/Demographics_of_Israel',
#    'name': 'Israel',
#    'population': '9339180',
#    'percent_of_world': '0.119'},
#   {'rank': '96',
#    'link': '/wiki/Demographics_of_Tajikistan',
#    'name': 'Tajikistan',
#    'population': '9313800',
#    'percent_of_world': '0.118'},
#   {'rank': '97',
#    'link': '/wiki/Demographics_of_Papua_New_Guinea',
#    'name': 'Papua New Guinea',
#    'population': '9122994',
#    'percent_of_world': '0.116'},
#   {'rank': '98',
#    'link': '/wiki/Demographics_of_Austria',
#    'name': 'Austria',
#    'population': '8933346',
#    'percent_of_world': '0.114'},
#   {'rank': '99',
#    'link': '/wiki/Demographics_of_Switzerland',
#    'name': 'Switzerland',
#    'population': '8667100',
#    'percent_of_world': '0.110'},
#   {'rank': '100',
#    'link': '/wiki/Demographics_of_Sierra_Leone',
#    'name': 'Sierra Leone',
#    'population': '8297882',
#    'percent_of_world': '0.106'},
#   {'rank': '101',
#    'link': '/wiki/Demographics_of_Togo',
#    'name': 'Togo',
#    'population': '7886000',
#    'percent_of_world': '0.100'},
#   {'rank': '–',
#    'link': '/wiki/Demographics_of_Hong_Kong',
#    'name': 'Hong Kong',
#    'population': '7474200',
#    'percent_of_world': '0.0951%'},
#   {'rank': '102',
#    'link': '/wiki/Demographics_of_Paraguay',
#    'name': 'Paraguay',
#    'population': '7353038',
#    'percent_of_world': '0.0935'},
#   {'rank': '103',
#    'link': '/wiki/Demographics_of_Laos',
#    'name': 'Laos',
#    'population': '7337783',
#    'percent_of_world': '0.0933'},
#   {'rank': '104',
#    'link': '/wiki/Demographics_of_Libya',
#    'name': 'Libya',
#    'population': '6959000',
#    'percent_of_world': '0.0885'},
#   {'rank': '105',
#    'link': '/wiki/Demographics_of_Serbia',
#    'name': 'Serbia',
#    'population': '6926705',
#    'percent_of_world': '0.0881'},
#   {'rank': '106',
#    'link': '/wiki/Demographics_of_Bulgaria',
#    'name': 'Bulgaria',
#    'population': '6916548',
#    'percent_of_world': '0.0880'},
#   {'rank': '107',
#    'link': '/wiki/Demographics_of_El_Salvador',
#    'name': 'El Salvador',
#    'population': '6825935',
#    'percent_of_world': '0.0868'},
#   {'rank': '108',
#    'link': '/wiki/Demographics_of_Lebanon',
#    'name': 'Lebanon',
#    'population': '6769000',
#    'percent_of_world': '0.0861'},
#   {'rank': '109',
#    'link': '/wiki/Demographics_of_Kyrgyzstan',
#    'name': 'Kyrgyzstan',
#    'population': '6645500',
#    'percent_of_world': '0.0845'},
#   {'rank': '110',
#    'link': '/wiki/Demographics_of_Nicaragua',
#    'name': 'Nicaragua',
#    'population': '6527691',
#    'percent_of_world': '0.0830'},
#   {'rank': '111',
#    'link': '/wiki/Demographics_of_Turkmenistan',
#    'name': 'Turkmenistan',
#    'population': '6118000',
#    'percent_of_world': '0.0778'},
#   {'rank': '112',
#    'link': '/wiki/Demographics_of_Denmark',
#    'name': 'Denmark',
#    'population': '5840045',
#    'percent_of_world': '0.0743'},
#   {'rank': '113',
#    'link': '/wiki/Demographics_of_Singapore',
#    'name': 'Singapore',
#    'population': '5685807',
#    'percent_of_world': '0.0723'},
#   {'rank': '114',
#    'link': '/wiki/Demographics_of_Republic_of_the_Congo',
#    'name': 'Congo',
#    'population': '5657000',
#    'percent_of_world': '0.0720'},
#   {'rank': '115',
#    'link': '/wiki/Demographics_of_Central_African_Republic',
#    'name': 'Central African Republic',
#    'population': '5633412',
#    'percent_of_world': '0.0717'},
#   {'rank': '116',
#    'link': '/wiki/Demographics_of_Finland',
#    'name': 'Finland',
#    'population': '5508198',
#    'percent_of_world': '0.0701'},
#   {'rank': '117',
#    'link': '/wiki/Demographics_of_Slovakia',
#    'name': 'Slovakia',
#    'population': '5459781',
#    'percent_of_world': '0.0694'},
#   {'rank': '118',
#    'link': '/wiki/Demographics_of_Norway',
#    'name': 'Norway',
#    'population': '5391369',
#    'percent_of_world': '0.0686'},
#   {'rank': '119',
#    'link': '/wiki/Demographics_of_Palestine',
#    'name': '',
#    'population': '5227193',
#    'percent_of_world': '0.0665'},
#   {'rank': '120',
#    'link': '/wiki/Demographics_of_Costa_Rica',
#    'name': 'Costa Rica',
#    'population': '5163038',
#    'percent_of_world': '0.0657'},
#   {'rank': '121',
#    'link': '/wiki/Demographics_of_New_Zealand',
#    'name': 'New Zealand',
#    'population': '5125096',
#    'percent_of_world': '0.0652'},
#   {'rank': '122',
#    'link': '/wiki/Demographics_of_the_Republic_of_Ireland',
#    'name': 'Ireland',
#    'population': '4977400',
#    'percent_of_world': '0.0633'},
#   {'rank': '123',
#    'link': '/wiki/Demographics_of_Liberia',
#    'name': 'Liberia',
#    'population': '4661010',
#    'percent_of_world': '0.0593'},
#   {'rank': '124',
#    'link': '/wiki/Demographics_of_Oman',
#    'name': 'Oman',
#    'population': '4496419',
#    'percent_of_world': '0.0572'},
#   {'rank': '125',
#    'link': '/wiki/Demographics_of_Kuwait',
#    'name': 'Kuwait',
#    'population': '4464521',
#    'percent_of_world': '0.0568'},
#   {'rank': '126',
#    'link': '/wiki/Demographics_of_Panama',
#    'name': 'Panama',
#    'population': '4278500',
#    'percent_of_world': '0.0544'},
#   {'rank': '127',
#    'link': '/wiki/Demographics_of_Mauritania',
#    'name': 'Mauritania',
#    'population': '4271197',
#    'percent_of_world': '0.0543'},
#   {'rank': '128',
#    'link': '/wiki/Demographics_of_Croatia',
#    'name': 'Croatia',
#    'population': '4047200',
#    'percent_of_world': '0.0515'},
#   {'rank': '129',
#    'link': '/wiki/Demographics_of_Georgia_(country)',
#    'name': 'Georgia',
#    'population': '3716858',
#    'percent_of_world': '0.0473'},
#   {'rank': '130',
#    'link': '/wiki/Demographics_of_Eritrea',
#    'name': 'Eritrea',
#    'population': '3601000',
#    'percent_of_world': '0.0458'},
#   {'rank': '131',
#    'link': '/wiki/Demographics_of_Uruguay',
#    'name': 'Uruguay',
#    'population': '3554915',
#    'percent_of_world': '0.0452'},
#   {'rank': '132',
#    'link': '/wiki/Demographics_of_Mongolia',
#    'name': 'Mongolia',
#    'population': '3373036',
#    'percent_of_world': '0.0429'},
#   {'rank': '133',
#    'link': '/wiki/Demographics_of_Bosnia_and_Herzegovina',
#    'name': 'Bosnia and Herzegovina',
#    'population': '3332593',
#    'percent_of_world': '0.0424'},
#   {'rank': '–',
#    'link': '/wiki/Demographics_of_Puerto_Rico',
#    'name': 'Puerto Rico',
#    'population': '3193694',
#    'percent_of_world': '0.0406'},
#   {'rank': '134',
#    'link': '/wiki/Demographics_of_Armenia',
#    'name': 'Armenia',
#    'population': '2967900',
#    'percent_of_world': '0.0378'},
#   {'rank': '135',
#    'link': '/wiki/Demographics_of_Albania',
#    'name': 'Albania',
#    'population': '2845955',
#    'percent_of_world': '0.0362'},
#   {'rank': '136',
#    'link': '/wiki/Demographics_of_Lithuania',
#    'name': 'Lithuania',
#    'population': '2787658',
#    'percent_of_world': '0.0355'},
#   {'rank': '137',
#    'link': '/wiki/Demographics_of_Jamaica',
#    'name': 'Jamaica',
#    'population': '2734093',
#    'percent_of_world': '0.0348'},
#   {'rank': '138',
#    'link': '/wiki/Demographics_of_Qatar',
#    'name': 'Qatar',
#    'population': '2717360',
#    'percent_of_world': '0.0346'},
#   {'rank': '139',
#    'link': '/wiki/Demographics_of_Moldova',
#    'name': 'Moldova',
#    'population': '2640438',
#    'percent_of_world': '0.0336'},
#   {'rank': '140',
#    'link': '/wiki/Demographics_of_Namibia',
#    'name': 'Namibia',
#    'population': '2550226',
#    'percent_of_world': '0.0324'},
#   {'rank': '141',
#    'link': '/wiki/Demographics_of_Botswana',
#    'name': 'Botswana',
#    'population': '2410338',
#    'percent_of_world': '0.0307'},
#   {'rank': '142',
#    'link': '/wiki/Demographics_of_The_Gambia',
#    'name': 'Gambia',
#    'population': '2335504',
#    'percent_of_world': '0.0297'},
#   {'rank': '143',
#    'link': '/wiki/Demographics_of_Gabon',
#    'name': 'Gabon',
#    'population': '2233272',
#    'percent_of_world': '0.0284'},
#   {'rank': '144',
#    'link': '/wiki/Demographics_of_Slovenia',
#    'name': 'Slovenia',
#    'population': '2111461',
#    'percent_of_world': '0.0269'},
#   {'rank': '145',
#    'link': '/wiki/Demographics_of_North_Macedonia',
#    'name': 'North Macedonia',
#    'population': '2076255',
#    'percent_of_world': '0.0264'},
#   {'rank': '146',
#    'link': '/wiki/Demographics_of_Lesotho',
#    'name': 'Lesotho',
#    'population': '2007201',
#    'percent_of_world': '0.0255'},
#   {'rank': '147',
#    'link': '/wiki/Demographics_of_Latvia',
#    'name': 'Latvia',
#    'population': '1891300',
#    'percent_of_world': '0.0241'},
#   {'rank': '–',
#    'link': '/wiki/Demographics_of_Kosovo',
#    'name': 'Kosovo',
#    'population': '1782115',
#    'percent_of_world': '0.0227'},
#   {'rank': '148',
#    'link': '/wiki/Demographics_of_Guinea-Bissau',
#    'name': 'Guinea-Bissau',
#    'population': '1646077',
#    'percent_of_world': '0.0209'},
#   {'rank': '149',
#    'link': '/wiki/Demographics_of_Bahrain',
#    'name': 'Bahrain',
#    'population': '1501635',
#    'percent_of_world': '0.0191'},
#   {'rank': '150',
#    'link': '/wiki/Demographics_of_Equatorial_Guinea',
#    'name': 'Equatorial Guinea',
#    'population': '1454789',
#    'percent_of_world': '0.0185'},
#   {'rank': '151',
#    'link': '/wiki/Demographics_of_Trinidad_and_Tobago',
#    'name': 'Trinidad and Tobago',
#    'population': '1366725',
#    'percent_of_world': '0.0174'},
#   {'rank': '152',
#    'link': '/wiki/Demographics_of_Estonia',
#    'name': 'Estonia',
#    'population': '1329460',
#    'percent_of_world': '0.0169'},
#   {'rank': '153',
#    'link': '/wiki/Demographics_of_East_Timor',
#    'name': 'East Timor',
#    'population': '1317780',
#    'percent_of_world': '0.0168'},
#   {'rank': '154',
#    'link': '/wiki/Demographics_of_Mauritius',
#    'name': 'Mauritius',
#    'population': '1266030',
#    'percent_of_world': '0.0161'},
#   {'rank': '155',
#    'link': '/wiki/Demographics_of_Eswatini',
#    'name': 'Eswatini',
#    'population': '1093238',
#    'percent_of_world': '0.0139'},
#   {'rank': '156',
#    'link': '/wiki/Demographics_of_Djibouti',
#    'name': 'Djibouti',
#    'population': '976107',
#    'percent_of_world': '0.0124'},
#   {'rank': '157',
#    'link': '/wiki/Demographics_of_Fiji',
#    'name': 'Fiji',
#    'population': '898402',
#    'percent_of_world': '0.0114'},
#   {'rank': '158',
#    'link': '/wiki/Demographics_of_Cyprus',
#    'name': 'Cyprus',
#    'population': '888005',
#    'percent_of_world': '0.0113'},
#   {'rank': '159',
#    'link': '/wiki/Demographics_of_Comoros',
#    'name': 'Comoros',
#    'population': '758316',
#    'percent_of_world': '0.00965'},
#   {'rank': '160',
#    'link': '/wiki/Demographics_of_Bhutan',
#    'name': 'Bhutan',
#    'population': '756129',
#    'percent_of_world': '0.00962'},
#   {'rank': '161',
#    'link': '/wiki/Demographics_of_Guyana',
#    'name': 'Guyana',
#    'population': '743699',
#    'percent_of_world': '0.00946'},
#   {'rank': '162',
#    'link': '/wiki/Demographics_of_Solomon_Islands',
#    'name': 'Solomon Islands',
#    'population': '728041',
#    'percent_of_world': '0.00926'},
#   {'rank': '–',
#    'link': '/wiki/Demographics_of_Macau',
#    'name': 'Macau',
#    'population': '683100',
#    'percent_of_world': '0.00869%'},
#   {'rank': '163',
#    'link': '/wiki/Demographics_of_Luxembourg',
#    'name': 'Luxembourg',
#    'population': '634730',
#    'percent_of_world': '0.00807'},
#   {'rank': '164',
#    'link': '/wiki/Demographics_of_Montenegro',
#    'name': 'Montenegro',
#    'population': '621873',
#    'percent_of_world': '0.00791'},
#   {'rank': '–',
#    'link': '/wiki/Demographics_of_Western_Sahara',
#    'name': 'Western Sahara',
#    'population': '612000',
#    'percent_of_world': '0.00778'},
#   {'rank': '165',
#    'link': '/wiki/Demographics_of_Suriname',
#    'name': 'Suriname',
#    'population': '590100',
#    'percent_of_world': '0.00751'},
#   {'rank': '166',
#    'link': '/wiki/Demographics_of_Cape_Verde',
#    'name': 'Cape Verde',
#    'population': '563198',
#    'percent_of_world': '0.00716'},
#   {'rank': '167',
#    'link': '/wiki/Demographics_of_Malta',
#    'name': 'Malta',
#    'population': '514564',
#    'percent_of_world': '0.00655'},
#   {'rank': '–',
#    'link': '/wiki/Demographics_of_Transnistria',
#    'name': 'Transnistria',
#    'population': '469000',
#    'percent_of_world': '0.00597'},
#   {'rank': '168',
#    'link': '/wiki/Demographics_of_Brunei',
#    'name': 'Brunei',
#    'population': '459500',
#    'percent_of_world': '0.00584'},
#   {'rank': '169',
#    'link': '/wiki/Demographics_of_Belize',
#    'name': 'Belize',
#    'population': '419199',
#    'percent_of_world': '0.00533'},
#   {'rank': '170',
#    'link': '/wiki/Demographics_of_The_Bahamas',
#    'name': 'Bahamas',
#    'population': '393450',
#    'percent_of_world': '0.00500'},
#   {'rank': '171',
#    'link': '/wiki/Demographics_of_Maldives',
#    'name': 'Maldives',
#    'population': '383135',
#    'percent_of_world': '0.00487'},
#   {'rank': '–',
#    'link': '/wiki/Demographics_of_Northern_Cyprus',
#    'name': 'Northern Cyprus',
#    'population': '372486',
#    'percent_of_world': '0.00474'},
#   {'rank': '172',
#    'link': '/wiki/Demographics_of_Iceland',
#    'name': 'Iceland',
#    'population': '368590',
#    'percent_of_world': '0.00469'},
#   {'rank': '173',
#    'link': '/wiki/Demographics_of_Vanuatu',
#    'name': 'Vanuatu',
#    'population': '301295',
#    'percent_of_world': '0.00383'},
#   {'rank': '174',
#    'link': '/wiki/Demographics_of_Barbados',
#    'name': 'Barbados',
#    'population': '288000',
#    'percent_of_world': '0.00366'},
#   {'rank': '–',
#    'link': '/wiki/Demographics_of_French_Polynesia',
#    'name': 'French Polynesia',
#    'population': '279890',
#    'percent_of_world': '0.00356'},
#   {'rank': '–',
#    'link': '/wiki/Demographics_of_New_Caledonia',
#    'name': 'New Caledonia',
#    'population': '273674',
#    'percent_of_world': '0.00348'},
#   {'rank': '–',
#    'link': '/wiki/Demographics_of_Abkhazia',
#    'name': 'Abkhazia',
#    'population': '245424',
#    'percent_of_world': '0.00312'},
#   {'rank': '175',
#    'link': '/wiki/Demographics_of_S%C3%A3o_Tom%C3%A9_and_Pr%C3%ADncipe',
#    'name': 'São Tomé and Príncipe',
#    'population': '214610',
#    'percent_of_world': '0.00273'},
#   {'rank': '176',
#    'link': '/wiki/Demographics_of_Samoa',
#    'name': 'Samoa',
#    'population': '199853',
#    'percent_of_world': '0.00254'},
#   {'rank': '177',
#    'link': '/wiki/Demographics_of_Saint_Lucia',
#    'name': 'Saint Lucia',
#    'population': '178696',
#    'percent_of_world': '0.00227'},
#   {'rank': '–',
#    'link': '/wiki/Demographics_of_Guam',
#    'name': 'Guam',
#    'population': '178306',
#    'percent_of_world': '0.00227'},
#   {'rank': '–',
#    'link': '/wiki/Demographics_of_Cura%C3%A7ao',
#    'name': 'Curaçao',
#    'population': '156223',
#    'percent_of_world': '0.00199'},
#   {'rank': '–',
#    'link': '/wiki/Republic_of_Artsakh',
#    'name': 'Republic of Artsakh',
#    'population': '148800',
#    'percent_of_world': '0.00189'},
#   {'rank': '178',
#    'link': '/wiki/Demographics_of_Kiribati',
#    'name': 'Kiribati',
#    'population': '120740',
#    'percent_of_world': '0.00154'},
#   {'rank': '179',
#    'link': '/wiki/Demographics_of_Grenada',
#    'name': 'Grenada',
#    'population': '113000',
#    'percent_of_world': '0.00144'},
#   {'rank': '–',
#    'link': '/wiki/Demographics_of_Aruba',
#    'name': 'Aruba',
#    'population': '111904',
#    'percent_of_world': '0.00142'},
#   {'rank': '180',
#    'link': '/wiki/Demographics_of_Saint_Vincent_and_the_Grenadines',
#    'name': 'Saint Vincent and the Grenadines',
#    'population': '110696',
#    'percent_of_world': '0.00141'},
#   {'rank': '–',
#    'link': '/wiki/Demographics_of_Jersey',
# ...
#    'name': 'Isle of Man',
#    'population': '83314',
#    'percent_of_world': '0.00106'},
#   {'rank': '185',
#    'link': '/wiki/Demographics_of_Andorra',
#    'name': 'Andorra',
#    'population': '78015',
#    'percent_of_world': '0.000992'},
#   {'rank': '186',
#    'link': '/wiki/Demographics_of_Dominica',
#    'name': 'Dominica',
#    'population': '72000',
#    'percent_of_world': '0.000916'},
#   {'rank': '–',
#    'link': '/wiki/Demographics_of_the_Cayman_Islands',
#    'name': 'Cayman Islands',
#    'population': '65786',
#    'percent_of_world': '0.000837'},
#   {'rank': '–',
#    'link': '/wiki/Demographics_of_Bermuda',
#    'name': 'Bermuda',
#    'population': '64055',
#    'percent_of_world': '0.000815'},
#   {'rank': '–',
#    'link': '/wiki/Demographics_of_Guernsey',
#    'name': 'Guernsey',
#    'population': '63155',
#    'percent_of_world': '0.000803'},
#   {'rank': '–',
#    'link': '/wiki/Demographics_of_American_Samoa',
#    'name': 'American Samoa',
#    'population': '56951',
#    'percent_of_world': '0.000724'},
#   {'rank': '–',
#    'link': '/wiki/Demographics_of_the_Northern_Mariana_Islands',
#    'name': 'Northern Mariana Islands',
#    'population': '56801',
#    'percent_of_world': '0.000722'},
#   {'rank': '–',
#    'link': '/wiki/Demographics_of_Greenland',
#    'name': 'Greenland',
#    'population': '56421',
#    'percent_of_world': '0.000718'},
#   {'rank': '187',
#    'link': '/wiki/Demographics_of_Marshall_Islands',
#    'name': 'Marshall Islands',
#    'population': '54516',
#    'percent_of_world': '0.000693'},
#   {'rank': '188',
#    'link': '/wiki/Demographics_of_Saint_Kitts_and_Nevis',
#    'name': 'Saint Kitts and Nevis',
#    'population': '54000',
#    'percent_of_world': '0.000687'},
#   {'rank': '–',
#    'link': '/wiki/Demographics_of_South_Ossetia',
#    'name': 'South Ossetia',
#    'population': '53532',
#    'percent_of_world': '0.000681'},
#   {'rank': '–',
#    'link': '/wiki/Demographics_of_Faroe_Islands',
#    'name': 'Faroe Islands',
#    'population': '53108',
#    'percent_of_world': '0.000676'},
#   {'rank': '–',
#    'link': '/wiki/Demographics_of_Turks_and_Caicos_Islands',
#    'name': 'Turks and Caicos Islands',
#    'population': '42953',
#    'percent_of_world': '0.000546'},
#   {'rank': '–',
#    'link': '/wiki/Demographics_of_Sint_Maarten',
#    'name': 'Sint Maarten',
#    'population': '40614',
#    'percent_of_world': '0.000517'},
#   {'rank': '189',
#    'link': '/wiki/Demographics_of_Liechtenstein',
#    'name': 'Liechtenstein',
#    'population': '39062',
#    'percent_of_world': '0.000497'},
#   {'rank': '190',
#    'link': '/wiki/Demographics_of_Monaco',
#    'name': 'Monaco',
#    'population': '38100',
#    'percent_of_world': '0.000485'},
#   {'rank': '–',
#    'link': '/wiki/Collectivity_of_Saint_Martin',
#    'name': '',
#    'population': '34065',
#    'percent_of_world': '0.000433'},
#   {'rank': '–',
#    'link': '/wiki/Demographics_of_Gibraltar',
#    'name': 'Gibraltar',
#    'population': '34003',
#    'percent_of_world': '0.000433'},
#   {'rank': '191',
#    'link': '/wiki/Demographics_of_San_Marino',
#    'name': 'San Marino',
#    'population': '33600',
#    'percent_of_world': '0.000427'},
#   {'rank': '–',
#    'link': '/wiki/%C3%85land_Islands',
#    'name': 'Åland Islands',
#    'population': '30152',
#    'percent_of_world': '0.000384'},
#   {'rank': '–',
#    'link': '/wiki/Demographics_of_the_British_Virgin_Islands',
#    'name': 'British Virgin Islands',
#    'population': '30000',
#    'percent_of_world': '0.000382'},
#   {'rank': '192',
#    'link': '/wiki/Demographics_of_Palau',
#    'name': 'Palau',
#    'population': '17957',
#    'percent_of_world': '0.000228'},
#   {'rank': '–',
#    'link': '/wiki/Demographics_of_Cook_Islands',
#    'name': 'Cook Islands',
#    'population': '15342',
#    'percent_of_world': '0.000195'},
#   {'rank': '–',
#    'link': '/wiki/Demographics_of_Anguilla',
#    'name': 'Anguilla',
#    'population': '15000',
#    'percent_of_world': '0.000191'},
#   {'rank': '193',
#    'link': '/wiki/Demographics_of_Nauru',
#    'name': 'Nauru',
#    'population': '11832',
#    'percent_of_world': '0.000150'},
#   {'rank': '–',
#    'link': '/wiki/Demographics_of_Wallis_and_Futuna',
#    'name': 'Wallis and Futuna',
#    'population': '11369',
#    'percent_of_world': '0.000145'},
#   {'rank': '194',
#    'link': '/wiki/Demographics_of_Tuvalu',
#    'name': 'Tuvalu',
#    'population': '10679',
#    'percent_of_world': '0.000136'},
#   {'rank': '–',
#    'link': '/wiki/Demographics_of_Saint_Barth%C3%A9lemy',
#    'name': 'Saint Barthélemy',
#    'population': '10124',
#    'percent_of_world': '0.000129'},
#   {'rank': '–',
#    'link': '/wiki/Demographics_of_Saint_Pierre_and_Miquelon',
#    'name': 'Saint Pierre and Miquelon',
#    'population': '5985',
#    'percent_of_world': '0'},
#   {'rank': '–',
#    'link': '/wiki/Demographics_of_Saint_Helena,_Ascension_and_Tristan_da_Cunha',
#    'name': 'Saint Helena, Ascensionand Tristan da Cunha',
#    'population': '5633',
#    'percent_of_world': '0'},
#   {'rank': '–',
#    'link': '/wiki/Demographics_of_Montserrat',
#    'name': 'Montserrat',
#    'population': '5000',
#    'percent_of_world': '0'},
#   {'rank': '–',
#    'link': '/wiki/Demographics_of_Falkland_Islands',
#    'name': 'Falkland Islands',
#    'population': '3398',
#    'percent_of_world': '0'},
#   {'rank': '–',
#    'link': '/wiki/Demographics_of_Christmas_Island',
#    'name': 'Christmas Island',
#    'population': '1966',
#    'percent_of_world': '00'},
#   {'rank': '–',
#    'link': '/wiki/Demographics_of_Norfolk_Island',
#    'name': 'Norfolk Island',
#    'population': '1734',
#    'percent_of_world': '0'},
#   {'rank': '–',
#    'link': '/wiki/Demographics_of_Niue',
#    'name': 'Niue',
#    'population': '1549',
#    'percent_of_world': '0'},
#   {'rank': '–',
#    'link': '/wiki/Demographics_of_Tokelau',
#    'name': 'Tokelau',
#    'population': '1501',
#    'percent_of_world': '0'},
#   {'rank': '195',
#    'link': '/wiki/Demographics_of_Vatican_City',
#    'name': 'Vatican City',
#    'population': '825',
#    'percent_of_world': '0'},
#   {'rank': '–',
#    'link': '/wiki/Demographics_of_Cocos_(Keeling)_Islands',
#    'name': 'Cocos (Keeling) Islands',
#    'population': '573',
#    'percent_of_world': '0'},
#   {'rank': '–',
#    'link': '/wiki/Demographics_of_Pitcairn_Islands',
#    'name': 'Pitcairn Islands',
#    'population': '40',
#    'percent_of_world': '0'}],
#  '_i4': 'def get_country_page(country_link):\n    """\n    function takes in a link to be appended to the base_url\n    it retrievs the HTML code from the page\n    \n    function feturns the Beautiful Soup object \n    that contains all the html code from that page\n    """\n    country_url = \'https://en.wikipedia.org\' + country_link\n    response = requests.get(country_url)\n    if response.status_code != 200: \n        print(\'Status code:\', response.status_code)\n        raise Exception(\'Failed to fetch web page \' + country_url)\n    soup = BeautifulSoup(response.text)\n    return soup\n\n# next get every row that has a <th> tag as the first header\ndef get_row_data(table_rows):\n    """\n    function takes in a list of all the html rows of the table\n    It then scrapes the data from each row of the table \n    returns a list of dictionaries of key value from each row\n   \n    If the row does not have a <td> tag then the row is a header break\n    and we should stop scraping because rows below are not easily parsable\n    """\n    info = []\n    for row in table_rows[1:]: #skip the first row because it is just the table title\n        if (row.td == None):\n            break  \n        elif row.td.has_attr(\'class\'): #if no \'class\' this not a row we want\n            if (row.td[\'class\'][0] == \'infobox-data\'): # list value for key returned so get [0]th element\n                info.append({row.th.text: row.td.text}) # make dict item in list\n    return info\n\ndef get_demographics(country_link):\n    """\n    function takes in the country link for Wiki\n    returns a dictionary with the items from the info table\n    returns None if there is no table or if not the table we want\n    """\n    soup = get_country_page(country_link) #retrieves the Beautiful soup Page\n    table = soup.find(\'table\', class_=\'infobox\') #finds the first table in the page\n    if table:\n        if table.has_attr(\'style\') and table.has_attr(\'class\'):#and table[\'style\']: #and table[\'style\'] == \'width: 25em\':\n            table_rows = table.find_all(\'tr\')\n            info = get_row_data(table_rows)\n            return info\n    return',
#  'get_country_page': <function __main__.get_country_page(country_link)>,
#  'get_row_data': <function __main__.get_row_data(table_rows)>,
#  'get_demographics': <function __main__.get_demographics(country_link)>,
#  '_i5': "country_info = get_demographics('/wiki/Demographics_of_the_United_States')\ncountry_info",
#  'country_info': [{'Population': '308,401,808\n(2010 Census[a]) (3rd)\n\n•\xa0Estimate\xa0329,484,123 (pre-2020 Census) (3rd)'},
#   {'Density': '86.16/sq\xa0mi (33.27/km2)'},
#   {'Growth rate': ' 0.72% (2020)[1]'},
#   {'Birth rate': '11.6 births/1,000 population (2020)[1]'},
#   {'Death rate': '8.9 deaths/1,000 population (2020)[1]'},
#   {'Life expectancy': '77.8 years (2020)[2]'},
#   {'Male': '75.1 years[2]'},
#   {'Female': '80.5 years[2]'},
#   {'Fertility rate': '1.706 children born/woman (2019)[3]'},
#   {'Net migration rate': '3 migrant(s)/1,000 population (2020)[1]'}],
#  '_5': [{'Population': '308,401,808\n(2010 Census[a]) (3rd)\n\n•\xa0Estimate\xa0329,484,123 (pre-2020 Census) (3rd)'},
#   {'Density': '86.16/sq\xa0mi (33.27/km2)'},
#   {'Growth rate': ' 0.72% (2020)[1]'},
#   {'Birth rate': '11.6 births/1,000 population (2020)[1]'},
#   {'Death rate': '8.9 deaths/1,000 population (2020)[1]'},
#   {'Life expectancy': '77.8 years (2020)[2]'},
#   {'Male': '75.1 years[2]'},
#   {'Female': '80.5 years[2]'},
#   {'Fertility rate': '1.706 children born/woman (2019)[3]'},
#   {'Net migration rate': '3 migrant(s)/1,000 population (2020)[1]'}],
#  '_i6': "# this removes the bullte of the Male/Female keys in the dictionaries\ndef parse_sex(country_info):\n    for index, item in enumerate(country_info): \n        for key in item:\n            if 'male' in key: # it could be male or female... \n                if 'female' in key:\n                    country_info[index] = {'Female': item[key]} \n                else: \n                    country_info[index] = {'Male': item[key]}",
#  'parse_sex': <function __main__.parse_sex(country_info)>,
#  '_i7': 'parse_sex(country_info)\ncountry_info',
#  '_7': [{'Population': '308,401,808\n(2010 Census[a]) (3rd)\n\n•\xa0Estimate\xa0329,484,123 (pre-2020 Census) (3rd)'},
#   {'Density': '86.16/sq\xa0mi (33.27/km2)'},
#   {'Growth rate': ' 0.72% (2020)[1]'},
#   {'Birth rate': '11.6 births/1,000 population (2020)[1]'},
#   {'Death rate': '8.9 deaths/1,000 population (2020)[1]'},
#   {'Life expectancy': '77.8 years (2020)[2]'},
#   {'Male': '75.1 years[2]'},
#   {'Female': '80.5 years[2]'},
#   {'Fertility rate': '1.706 children born/woman (2019)[3]'},
#   {'Net migration rate': '3 migrant(s)/1,000 population (2020)[1]'}],
#  '_i8': "country_df = pd.read_csv('country_list.csv')\ncountry_df",
#  'country_df':     rank                                           link  \
#  0      1                    /wiki/Demographics_of_China
#  1      2                    /wiki/Demographics_of_India
#  2      3        /wiki/Demographics_of_the_United_States
#  3      4                /wiki/Demographics_of_Indonesia
#  4      5                 /wiki/Demographics_of_Pakistan
#  ..   ...                                            ...
#  236    –                     /wiki/Demographics_of_Niue
#  237    –                  /wiki/Demographics_of_Tokelau
#  238  195             /wiki/Demographics_of_Vatican_City
#  239    –  /wiki/Demographics_of_Cocos_(Keeling)_Islands
#  240    –         /wiki/Demographics_of_Pitcairn_Islands
#
#                          name  population percent_of_world
#  0                      China  1407562280             17.9
#  1                      India  1375875687             17.5
#  2              United States   331520958             4.22
#  3                  Indonesia   271350000             3.45
#  4                   Pakistan   225200000             2.86
#  ..                       ...         ...              ...
#  236                     Niue        1549                0
#  237                  Tokelau        1501                0
#  238             Vatican City         825                0
#  239  Cocos (Keeling) Islands         573                0
#  240         Pitcairn Islands          40                0
#
#  [241 rows x 5 columns],
#  '_8':     rank                                           link  \
#  0      1                    /wiki/Demographics_of_China
#  1      2                    /wiki/Demographics_of_India
#  2      3        /wiki/Demographics_of_the_United_States
#  3      4                /wiki/Demographics_of_Indonesia
#  4      5                 /wiki/Demographics_of_Pakistan
#  ..   ...                                            ...
#  236    –                     /wiki/Demographics_of_Niue
#  237    –                  /wiki/Demographics_of_Tokelau
#  238  195             /wiki/Demographics_of_Vatican_City
#  239    –  /wiki/Demographics_of_Cocos_(Keeling)_Islands
#  240    –         /wiki/Demographics_of_Pitcairn_Islands
#
#                          name  population percent_of_world
#  0                      China  1407562280             17.9
#  1                      India  1375875687             17.5
#  2              United States   331520958             4.22
#  3                  Indonesia   271350000             3.45
#  4                   Pakistan   225200000             2.86
#  ..                       ...         ...              ...
#  236                     Niue        1549                0
#  237                  Tokelau        1501                0
#  238             Vatican City         825                0
#  239  Cocos (Keeling) Islands         573                0
#  240         Pitcairn Islands          40                0
#
#  [241 rows x 5 columns],
#  '_i9': "demo_links = country_df['link']\n\ncount = 0\nfor link in demo_links:\n    temp = get_demographics(link)\n    if temp == None:\n        count += 1\n    print(temp)\n    \n    ",
#  'demo_links': 0                        /wiki/Demographics_of_China
#  1                        /wiki/Demographics_of_India
#  2            /wiki/Demographics_of_the_United_States
#  3                    /wiki/Demographics_of_Indonesia
#  4                     /wiki/Demographics_of_Pakistan
#                             ...
#  236                       /wiki/Demographics_of_Niue
#  237                    /wiki/Demographics_of_Tokelau
#  238               /wiki/Demographics_of_Vatican_City
#  239    /wiki/Demographics_of_Cocos_(Keeling)_Islands
#  240           /wiki/Demographics_of_Pitcairn_Islands
#  Name: link, Length: 241, dtype: object,
#  'count': 161,
#  'link': '/wiki/Demographics_of_Pitcairn_Islands',
#  'temp': None,
#  'validate_api_key': <function jovian.utils.credentials.validate_api_key(key)>,
#  'read_api_key_opt': <function jovian.utils.credentials.read_api_key_opt()>,
#  'creds_exist': <function jovian.utils.credentials.creds_exist()>,
#  'key_status': 'valid',
#  'current_key': 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpYXQiOjE2MTgyNDYzOTksIm5iZiI6MTYxODI0NjM5OSwianRpIjoiNjZhNWUxNTQtYjUzOS00OWYyLTk1M2UtYTU1ZTI3YjQxNGI5IiwiZXhwIjoxNjIyMTM0Mzk5LCJpZGVudGl0eSI6eyJpZCI6MjQ0NzMsInVzZXJuYW1lIjoic2FtYW50aGEtcm9iZXJ0cyJ9LCJmcmVzaCI6ZmFsc2UsInR5cGUiOiJhY2Nlc3MifQ.A-WpzlOzNlyjvLu_F_aT3VTcsJ2YZPSUb_JacSibEzE',
#  'redirect_stdout': contextlib.redirect_stdout,
#  'redirect_stderr': contextlib.redirect_stderr,
#  'StringIO': _io.StringIO,
#  'json': <module 'json' from 'C:\\Users\\Sam\\anaconda3\\lib\\json\\__init__.py'>,
#  'commit': <function jovian.utils.commit.commit(message=None, files=[], outputs=[], environment='auto', privacy='auto', filename=None, project=None, new_project=None, git_commit=False, git_message='auto', **kwargs)>,
#  '_i10': 'None in temp',
#  '_i11': 'None in temp[0]',
#  '_i12': 'temp[0]',
#  '_i13': 'temp[1]',
#  '_i14': 'temp',
#  '_i15': 'locals()'}
