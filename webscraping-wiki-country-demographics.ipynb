# %% [markdown]
# **Jovian Project #1 Web Scraping**
# **Author: Samantha Roberts**
# **Date: April 21, 2021**

# %% [markdown]
# # Webscraping Wikipedia Country Demographics Pages
#
# I am very interested in geography and learning statistics about other countries in the world.  I frequently use Wikipedia to quickly get this information.  **In this project I will show how I used Python programming libraries (Beautiful Soup, Requests, Pandas) to gather demographic information about the many countries of the world by scraping Wikipedia web pages.**
#
# Wikipedia is a collaborative online publicly editable encyclopedia.  It is the largest and most-read reference work in history, and consistently one of the 15 most popular websites visited[Ref](https://www.economist.com/international/2021/01/09/wikipedia-is-20-and-its-reputation-has-never-been-higher). Though anyone in theory can edit a wiki page, there are some light governances in effect that attempt to suggest how some pages are structured.  One of the ways that this can be done is via [WikiProjects](https://en.wikipedia.org/wiki/Wikipedia:WikiProject), where a group of contriburors attempt to work together as a team to improve a topic, often by attempting to standardize it to some extent.  ["Demographics"](https://en.wikipedia.org/wiki/Wikipedia:WikiProject_Demographics) is one such WikiProject.  In this project, each country has a demographics page, and many of these pages have a table that would be displayed in the right hand colum of each country page.  This table contains information on things like population breakdown by race, sex, religion, population density, birth and death rate, language, government type and so forth. **It is this demographics summary table that this project attempts to find and scrape for each country of the world.**
#
# <img src="https://i.imgur.com/T9OASLH.png" width="80%">.

# %% [markdown]
# ## Two Principal Challenges:
# 1. Though there was a suggested standard for how the individual country demographic pages were to be displayed, I quickly found out that this standard was not maintained over the over 220 pages for all the countries and territories of the world.
# 2. As wiki is publically editable, ([1.9 pages per second are edited!](https://en.wikipedia.org/wiki/Wikipedia:Statistics#:~:text=It%20may%20reflect%20varying%20levels%20of%20consensus%20and%20vetting.&text=While%20you%20read%20this%2C%20Wikipedia,598%20new%20articles%20per%20day.)), sometimes the scraping algorithim would stop working because a page had been modified since my last edit.
#
# **I will show how I dealt with the challenges of the non-standardized Wiki format, and how I was able to automate the scraping of 80 individual Wikipedia country pages.**

# %% [markdown]
# ## Project Steps:
#
# 1. **Scrape the main demographics page to build a list of countries and their Wiki-links**
#     - Using the python Requests and Beautiful Soup librarys we will scrape the [Wikipedia page](https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population) that lists the links of all county wiki pages
#     - Parsing the HTML data we will make a list of dictionaries, 1 dictionary for each country that contains the country name and the link to the individual page
#     - Using Pandas, we will read this data into a CSV file
#
#
# 2. **Scrape individual country pages for their demographics**
#
#     - Read the countries and links into a dataframe using Pandas
#     - Crawl the links in the CSV file and see how many country pages have the table I am trying to scrape
#     - Write code specific to the majority of demographics page tables to scrape the data I want
#     - Handle instances where the relevant tables do not exist in the demographics page
#
#
# 3. **Clean the data scraped**
#
#     - Look at the data in Pandas and see if there is some 1st order way to clean the data further
#     - Write the demographics info to a CSV file

# %% [markdown]
# ***
# <h1><center>OK - Lets Get Started!</center></h1>

# %% [markdown]
# # (Step 1)  Build a list of countries and their relative Wikipedia links
#
# 1. Scrape https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population
# 2. Put the rows of the HTML table into a dictionary
# 3. Convert the dictionary to a Pandas DataFrame and write it to a CSV file
#
# <img src="https://i.imgur.com/OzJpHZ7.png" width="80%">

# %% [markdown]
# ### Below are all the Python functions necessary to scrape the main demographics page, select the main table, build the dictionary, and write this data to a CSV file.

# %%
# now lets get all of the countries from the table
# ths is from the table at https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population

from bs4 import BeautifulSoup
import pandas as pd
import requests

def get_headers(table_header_row):
    """
    Takes a HTML table header
    returns a list of strings of the headers
    """
    cols = []
    for col in table_header_row:
        cols.append(col.text.strip()) 
    return cols[:4] # we dont want the date or the source references

def get_row_values(country): 
    """
    takes in HTML for a row of table data
    returns a dictionary of that data
    """
    info = {
            'rank': country.th.text.strip(),
            'link': country.a['href'],
            'name': country.a.text.strip(),
            'population': country.find('td', style='text-align:right').text.strip().replace(',',""),
            'percent_of_world': country.find_all('td', style='text-align:right')[1].text \
                                .replace('"', '').strip().strip('%')
            }
    return info

def build_country_list(rows):
    """
    take in a beautiful soup object containing rows of an HTML table
    returns a list of dictionaries each containing the data from each row
    """
    country_list = []
    for row in rows:
        country_list.append(get_row_values(row))
    return country_list

def scrape_wiki_table():
    """
    does what it says
    returns a list of dictionaries
    """
    world_countries_url = 'https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population'
    soup = BeautifulSoup(requests.get(world_countries_url).text)
    tables = soup.find_all('table', class_='wikitable sortable plainrowheaders')
    rows = tables[0].find_all('tr')
    #headers = get_headers(rows[0].find_all('th'))
    return build_country_list(rows[1:242])

def write_csv(path, list_of_dicts):
    """
    writes a list of dicts to a csv
    """
    df = pd.DataFrame(list_of_dicts)
    df.to_csv(path, index=False, header=True)

# %%
country_list = scrape_wiki_table()
write_csv('country_list.csv', country_list)

# %% [markdown]
# ### We see we have scraped information of 241 countries and dependencies
#
# * We created a list that contains the data scraped for each country in a dictionary
# * Each country dictionary that contains the following information:
#
#    * rank by population
#    * relative link on the wikipedia site
#    * country name
#    * population
#    * percent of the world

# %%
len(country_list)
# Out:
# 241

# %%
country_list[:]
# Out:
# [{'rank': '1',
#   'link': '/wiki/Demographics_of_China',
#   'name': 'China',
#   'population': '1407809120',
#   'percent_of_world': '17.9'},
#  {'rank': '2',
#   'link': '/wiki/Demographics_of_India',
#   'name': 'India',
#   'population': '1376560090',
#   'percent_of_world': '17.5'},
#  {'rank': '3',
#   'link': '/wiki/Demographics_of_the_United_States',
#   'name': 'United States',
#   'population': '331616914',
#   'percent_of_world': '4.22'},
#  {'rank': '4',
#   'link': '/wiki/Demographics_of_Indonesia',
#   'name': 'Indonesia',
#   'population': '271350000',
#   'percent_of_world': '3.45'},
#  {'rank': '5',
#   'link': '/wiki/Demographics_of_Pakistan',
#   'name': 'Pakistan',
#   'population': '225200000',
#   'percent_of_world': '2.86'},
#  {'rank': '6',
#   'link': '/wiki/Demographics_of_Brazil',
#   'name': 'Brazil',
#   'population': '213093087',
#   'percent_of_world': '2.71'},
#  {'rank': '7',
#   'link': '/wiki/Demographics_of_Nigeria',
#   'name': 'Nigeria',
#   'population': '211401000',
#   'percent_of_world': '2.69'},
#  {'rank': '8',
#   'link': '/wiki/Demographics_of_Bangladesh',
#   'name': 'Bangladesh',
#   'population': '170611068',
#   'percent_of_world': '2.17'},
#  {'rank': '9',
#   'link': '/wiki/Demographics_of_Russia',
#   'name': 'Russia',
#   'population': '146171015',
#   'percent_of_world': '1.86'},
#  {'rank': '10',
#   'link': '/wiki/Demographics_of_Mexico',
#   'name': 'Mexico',
#   'population': '126014024',
#   'percent_of_world': '1.60'},
#  {'rank': '11',
#   'link': '/wiki/Demographics_of_Japan',
#   'name': 'Japan',
#   'population': '125410000',
#   'percent_of_world': '1.59'},
#  {'rank': '12',
#   'link': '/wiki/Demographics_of_Ethiopia',
#   'name': 'Ethiopia',
#   'population': '117876000',
#   'percent_of_world': '1.50'},
#  {'rank': '13',
#   'link': '/wiki/Demographics_of_Philippines',
#   'name': 'Philippines',
#   'population': '110180504',
#   'percent_of_world': '1.40'},
#  {'rank': '14',
#   'link': '/wiki/Demographics_of_Egypt',
#   'name': 'Egypt',
#   'population': '101828736',
#   'percent_of_world': '1.29'},
#  {'rank': '15',
#   'link': '/wiki/Demographics_of_Vietnam',
#   'name': 'Vietnam',
#   'population': '97580000',
#   'percent_of_world': '1.24'},
#  {'rank': '16',
#   'link': '/wiki/Demographics_of_Democratic_Republic_of_the_Congo',
#   'name': 'DR Congo',
#   'population': '92378000',
#   'percent_of_world': '1.17'},
#  {'rank': '17',
#   'link': '/wiki/Demographics_of_Iran',
#   'name': 'Iran',
#   'population': '84416887',
#   'percent_of_world': '1.07'},
#  {'rank': '18',
#   'link': '/wiki/Demographics_of_Turkey',
#   'name': 'Turkey',
#   'population': '83614362',
#   'percent_of_world': '1.06'},
#  {'rank': '19',
#   'link': '/wiki/Demographics_of_Germany',
#   'name': 'Germany',
#   'population': '83190556',
#   'percent_of_world': '1.06'},
#  {'rank': '20',
#   'link': '/wiki/Demographics_of_France',
#   'name': 'France',
#   'population': '67406000',
#   'percent_of_world': '0.857'},
#  {'rank': '21',
#   'link': '/wiki/Demographics_of_United_Kingdom',
#   'name': 'United Kingdom',
#   'population': '66796807',
#   'percent_of_world': '0.849'},
#  {'rank': '22',
#   'link': '/wiki/Demographics_of_Thailand',
#   'name': 'Thailand',
#   'population': '66642830',
#   'percent_of_world': '0.847'},
#  {'rank': '23',
#   'link': '/wiki/Demographics_of_South_Africa',
#   'name': 'South Africa',
#   'population': '59622350',
#   'percent_of_world': '0.758'},
#  {'rank': '24',
#   'link': '/wiki/Demographics_of_Tanzania',
#   'name': 'Tanzania',
#   'population': '59441988',
#   'percent_of_world': '0.756'},
#  {'rank': '25',
#   'link': '/wiki/Demographics_of_Italy',
#   'name': 'Italy',
#   'population': '59226539',
#   'percent_of_world': '0.753'},
#  {'rank': '26',
#   'link': '/wiki/Demographics_of_Myanmar',
#   'name': 'Myanmar',
#   'population': '55294979',
#   'percent_of_world': '0.703'},
#  {'rank': '27',
#   'link': '/wiki/Demographics_of_South_Korea',
#   'name': 'South Korea',
#   'population': '51702100',
#   'percent_of_world': '0.657'},
#  {'rank': '28',
#   'link': '/wiki/Demographics_of_Colombia',
#   'name': 'Colombia',
#   'population': '51049498',
#   'percent_of_world': '0.649'},
#  {'rank': '29',
#   'link': '/wiki/Demographics_of_Kenya',
#   'name': 'Kenya',
#   'population': '47564296',
#   'percent_of_world': '0.605'},
#  {'rank': '30',
#   'link': '/wiki/Demographics_of_Spain',
#   'name': 'Spain',
#   'population': '47351567',
#   'percent_of_world': '0.602'},
#  {'rank': '31',
#   'link': '/wiki/Demographics_of_Argentina',
#   'name': 'Argentina',
#   'population': '45808747',
#   'percent_of_world': '0.582'},
#  {'rank': '32',
#   'link': '/wiki/Demographics_of_Algeria',
#   'name': 'Algeria',
#   'population': '44700000',
#   'percent_of_world': '0.568'},
#  {'rank': '33',
#   'link': '/wiki/Demographics_of_Sudan',
#   'name': 'Sudan',
#   'population': '43441870',
#   'percent_of_world': '0.552'},
#  {'rank': '34',
#   'link': '/wiki/Demographics_of_Uganda',
#   'name': 'Uganda',
#   'population': '42885900',
#   'percent_of_world': '0.545'},
#  {'rank': '35',
#   'link': '/wiki/Demographics_of_Ukraine',
#   'name': 'Ukraine',
#   'population': '41527205',
#   'percent_of_world': '0.528'},
#  {'rank': '36',
#   'link': '/wiki/Demographics_of_Iraq',
#   'name': 'Iraq',
#   'population': '41190700',
#   'percent_of_world': '0.524'},
#  {'rank': '37',
#   'link': '/wiki/Population_of_Canada',
#   'name': 'Canada',
#   'population': '38444634',
#   'percent_of_world': '0.489'},
#  {'rank': '38',
#   'link': '/wiki/Demographics_of_Poland',
#   'name': 'Poland',
#   'population': '38230000',
#   'percent_of_world': '0.486'},
#  {'rank': '39',
#   'link': '/wiki/Demographics_of_Morocco',
#   'name': 'Morocco',
#   'population': '36240494',
#   'percent_of_world': '0.461'},
#  {'rank': '40',
#   'link': '/wiki/Demographics_of_Uzbekistan',
#   'name': 'Uzbekistan',
#   'population': '34843661',
#   'percent_of_world': '0.443'},
#  {'rank': '41',
#   'link': '/wiki/Demographics_of_Saudi_Arabia',
#   'name': 'Saudi Arabia',
#   'population': '34218169',
#   'percent_of_world': '0.435'},
#  {'rank': '42',
#   'link': '/wiki/Demographics_of_Peru',
#   'name': 'Peru',
#   'population': '33035304',
#   'percent_of_world': '0.420'},
#  {'rank': '43',
#   'link': '/wiki/Demographics_of_Afghanistan',
#   'name': 'Afghanistan',
#   'population': '32890171',
#   'percent_of_world': '0.418'},
#  {'rank': '44',
#   'link': '/wiki/Demographics_of_Malaysia',
#   'name': 'Malaysia',
#   'population': '32771260',
#   'percent_of_world': '0.417'},
#  {'rank': '45',
#   'link': '/wiki/Demographics_of_Angola',
#   'name': 'Angola',
#   'population': '32097671',
#   'percent_of_world': '0.408'},
#  {'rank': '46',
#   'link': '/wiki/Demographics_of_Ghana',
#   'name': 'Ghana',
#   'population': '30955202',
#   'percent_of_world': '0.394'},
#  {'rank': '47',
#   'link': '/wiki/Demographics_of_Mozambique',
#   'name': 'Mozambique',
#   'population': '30832244',
#   'percent_of_world': '0.392'},
#  {'rank': '48',
#   'link': '/wiki/Demographics_of_Yemen',
#   'name': 'Yemen',
#   'population': '30491000',
#   'percent_of_world': '0.388'},
#  {'rank': '49',
#   'link': '/wiki/Demographics_of_Nepal',
#   'name': 'Nepal',
#   'population': '30378055',
#   'percent_of_world': '0.386'},
#  {'rank': '50',
#   'link': '/wiki/Demographics_of_Venezuela',
#   'name': 'Venezuela',
#   'population': '28705000',
#   'percent_of_world': '0.365'},
#  {'rank': '51',
#   'link': '/wiki/Demographics_of_Ivory_Coast',
#   'name': 'Ivory Coast',
#   'population': '27087732',
#   'percent_of_world': '0.344'},
#  {'rank': '52',
#   'link': '/wiki/Demographics_of_Madagascar',
#   'name': 'Madagascar',
#   'population': '26923353',
#   'percent_of_world': '0.342'},
#  {'rank': '53',
#   'link': '/wiki/Demographics_of_Australia',
#   'name': 'Australia',
#   'population': '25791873',
#   'percent_of_world': '0.328'},
#  {'rank': '54',
#   'link': '/wiki/Demographics_of_North_Korea',
#   'name': 'North Korea',
#   'population': '25660000',
#   'percent_of_world': '0.326'},
#  {'rank': '55',
#   'link': '/wiki/Demographics_of_Cameroon',
#   'name': 'Cameroon',
#   'population': '24348251',
#   'percent_of_world': '0.310'},
#  {'rank': '56',
#   'link': '/wiki/Demographics_of_Niger',
#   'name': 'Niger',
#   'population': '24112753',
#   'percent_of_world': '0.307'},
#  {'rank': '–',
#   'link': '/wiki/Demographics_of_Taiwan',
#   'name': 'Taiwan',
#   'population': '23525623',
#   'percent_of_world': '0.299'},
#  {'rank': '57',
#   'link': '/wiki/Demographics_of_Sri_Lanka',
#   'name': 'Sri Lanka',
#   'population': '21919000',
#   'percent_of_world': '0.279'},
#  {'rank': '58',
#   'link': '/wiki/Demographics_of_Burkina_Faso',
#   'name': 'Burkina Faso',
#   'population': '21510181',
#   'percent_of_world': '0.273'},
#  {'rank': '59',
#   'link': '/wiki/Demographics_of_Mali',
#   'name': 'Mali',
#   'population': '20856000',
#   'percent_of_world': '0.265'},
#  {'rank': '60',
#   'link': '/wiki/Demographics_of_Chile',
#   'name': 'Chile',
#   'population': '19678363',
#   'percent_of_world': '0.250'},
#  {'rank': '61',
#   'link': '/wiki/Demographics_of_Romania',
#   'name': 'Romania',
#   'population': '19317984',
#   'percent_of_world': '0.246'},
#  {'rank': '62',
#   'link': '/wiki/Demographics_of_Kazakhstan',
#   'name': 'Kazakhstan',
#   'population': '18919640',
#   'percent_of_world': '0.241'},
#  {'rank': '63',
#   'link': '/wiki/Demographics_of_Malawi',
#   'name': 'Malawi',
#   'population': '18898441',
#   'percent_of_world': '0.240'},
#  {'rank': '64',
#   'link': '/wiki/Demographics_of_Zambia',
#   'name': 'Zambia',
#   'population': '18400556',
#   'percent_of_world': '0.234'},
#  {'rank': '65',
#   'link': '/wiki/Demographics_of_Syria',
#   'name': 'Syria',
#   'population': '18276000',
#   'percent_of_world': '0.232'},
#  {'rank': '66',
#   'link': '/wiki/Demographics_of_Ecuador',
#   'name': 'Ecuador',
#   'population': '17725772',
#   'percent_of_world': '0.225'},
#  {'rank': '67',
#   'link': '/wiki/Demographics_of_Netherlands',
#   'name': 'Netherlands',
#   'population': '17590331',
#   'percent_of_world': '0.224'},
#  {'rank': '68',
#   'link': '/wiki/Demographics_of_Senegal',
#   'name': 'Senegal',
#   'population': '17223497',
#   'percent_of_world': '0.219'},
#  {'rank': '69',
#   'link': '/wiki/Demographics_of_Guatemala',
#   'name': 'Guatemala',
#   'population': '17109746',
#   'percent_of_world': '0.218'},
#  {'rank': '70',
#   'link': '/wiki/Demographics_of_Chad',
#   'name': 'Chad',
#   'population': '16818391',
#   'percent_of_world': '0.214'},
#  {'rank': '71',
#   'link': '/wiki/Demographics_of_Somalia',
#   'name': 'Somalia',
#   'population': '16360000',
#   'percent_of_world': '0.208'},
#  {'rank': '72',
#   'link': '/wiki/Demographics_of_Zimbabwe',
#   'name': 'Zimbabwe',
#   'population': '15790716',
#   'percent_of_world': '0.201'},
#  {'rank': '73',
#   'link': '/wiki/Demographics_of_Cambodia',
#   'name': 'Cambodia',
#   'population': '15552211',
#   'percent_of_world': '0.198'},
#  {'rank': '74',
#   'link': '/wiki/Demographics_of_South_Sudan',
#   'name': 'South Sudan',
#   'population': '13249924',
#   'percent_of_world': '0.168'},
#  {'rank': '75',
#   'link': '/wiki/Demographics_of_Rwanda',
#   'name': 'Rwanda',
#   'population': '12955768',
#   'percent_of_world': '0.165'},
#  {'rank': '76',
#   'link': '/wiki/Demographics_of_Guinea',
#   'name': 'Guinea',
#   'population': '12907395',
#   'percent_of_world': '0.164'},
#  {'rank': '77',
#   'link': '/wiki/Demographics_of_Burundi',
#   'name': 'Burundi',
#   'population': '12574571',
#   'percent_of_world': '0.160'},
#  {'rank': '78',
#   'link': '/wiki/Demographics_of_Benin',
#   'name': 'Benin',
#   'population': '12506347',
#   'percent_of_world': '0.159'},
#  {'rank': '79',
#   'link': '/wiki/Demographics_of_Bolivia',
#   'name': 'Bolivia',
#   'population': '11797257',
#   'percent_of_world': '0.150'},
#  {'rank': '80',
#   'link': '/wiki/Demographics_of_Tunisia',
#   'name': 'Tunisia',
#   'population': '11746695',
#   'percent_of_world': '0.149'},
#  {'rank': '81',
#   'link': '/wiki/Demographics_of_Haiti',
#   'name': 'Haiti',
#   'population': '11743017',
#   'percent_of_world': '0.149'},
#  {'rank': '82',
#   'link': '/wiki/Demographics_of_Belgium',
#   'name': 'Belgium',
#   'population': '11560220',
#   'percent_of_world': '0.147'},
#  {'rank': '83',
#   'link': '/wiki/Demographics_of_Cuba',
#   'name': 'Cuba',
#   'population': '11193470',
#   'percent_of_world': '0.142'},
#  {'rank': '84',
#   'link': '/wiki/Demographics_of_Jordan',
#   'name': 'Jordan',
#   'population': '10937548',
#   'percent_of_world': '0.139'},
#  {'rank': '85',
#   'link': '/wiki/Demographics_of_Greece',
#   'name': 'Greece',
#   'population': '10718565',
#   'percent_of_world': '0.136'},
#  {'rank': '86',
#   'link': '/wiki/Demographics_of_Czech_Republic',
#   'name': 'Czech Republic',
#   'population': '10701777',
#   'percent_of_world': '0.136'},
#  {'rank': '87',
#   'link': '/wiki/Demographics_of_Dominican_Republic',
#   'name': 'Dominican Republic',
#   'population': '10535535',
#   'percent_of_world': '0.134'},
#  {'rank': '88',
#   'link': '/wiki/Demographics_of_Sweden',
#   'name': 'Sweden',
#   'population': '10385347',
#   'percent_of_world': '0.132'},
#  {'rank': '89',
#   'link': '/wiki/Demographics_of_Portugal',
#   'name': 'Portugal',
#   'population': '10295909',
#   'percent_of_world': '0.131'},
#  {'rank': '90',
#   'link': '/wiki/Demographics_of_Azerbaijan',
#   'name': 'Azerbaijan',
#   'population': '10122148',
#   'percent_of_world': '0.129'},
#  {'rank': '91',
#   'link': '/wiki/Demographics_of_Hungary',
#   'name': 'Hungary',
#   'population': '9730000',
#   'percent_of_world': '0.124'},
#  {'rank': '92',
#   'link': '/wiki/Demographics_of_United_Arab_Emirates',
#   'name': 'United Arab Emirates',
#   'population': '9503738',
#   'percent_of_world': '0.121'},
#  {'rank': '93',
#   'link': '/wiki/Demographics_of_Honduras',
#   'name': 'Honduras',
#   'population': '9450711',
#   'percent_of_world': '0.120'},
#  {'rank': '94',
#   'link': '/wiki/Demographics_of_Belarus',
#   'name': 'Belarus',
#   'population': '9349645',
#   'percent_of_world': '0.119'},
#  {'rank': '95',
#   'link': '/wiki/Demographics_of_Israel',
#   'name': 'Israel',
#   'population': '9341055',
#   'percent_of_world': '0.119'},
#  {'rank': '96',
#   'link': '/wiki/Demographics_of_Tajikistan',
#   'name': 'Tajikistan',
#   'population': '9313800',
#   'percent_of_world': '0.118'},
#  {'rank': '97',
#   'link': '/wiki/Demographics_of_Papua_New_Guinea',
#   'name': 'Papua New Guinea',
#   'population': '9122994',
#   'percent_of_world': '0.116'},
#  {'rank': '98',
#   'link': '/wiki/Demographics_of_Austria',
#   'name': 'Austria',
#   'population': '8933346',
#   'percent_of_world': '0.114'},
#  {'rank': '99',
#   'link': '/wiki/Demographics_of_Switzerland',
#   'name': 'Switzerland',
#   'population': '8667100',
#   'percent_of_world': '0.110'},
#  {'rank': '100',
#   'link': '/wiki/Demographics_of_Sierra_Leone',
#   'name': 'Sierra Leone',
#   'population': '8297882',
#   'percent_of_world': '0.105'},
#  {'rank': '101',
#   'link': '/wiki/Demographics_of_Togo',
#   'name': 'Togo',
#   'population': '7886000',
#   'percent_of_world': '0.100'},
#  {'rank': '–',
#   'link': '/wiki/Demographics_of_Hong_Kong',
#   'name': 'Hong Kong',
#   'population': '7474200',
#   'percent_of_world': '0.0950'},
#  {'rank': '102',
#   'link': '/wiki/Demographics_of_Paraguay',
#   'name': 'Paraguay',
#   'population': '7353038',
#   'percent_of_world': '0.0935'},
#  {'rank': '103',
#   'link': '/wiki/Demographics_of_Laos',
#   'name': 'Laos',
#   'population': '7337783',
#   'percent_of_world': '0.0933'},
#  {'rank': '104',
#   'link': '/wiki/Demographics_of_Libya',
#   'name': 'Libya',
#   'population': '6959000',
#   'percent_of_world': '0.0885'},
#  {'rank': '105',
#   'link': '/wiki/Demographics_of_Serbia',
#   'name': 'Serbia',
#   'population': '6926705',
#   'percent_of_world': '0.0881'},
#  {'rank': '106',
#   'link': '/wiki/Demographics_of_Bulgaria',
#   'name': 'Bulgaria',
#   'population': '6916548',
#   'percent_of_world': '0.0879'},
#  {'rank': '107',
#   'link': '/wiki/Demographics_of_El_Salvador',
#   'name': 'El Salvador',
#   'population': '6825935',
#   'percent_of_world': '0.0868'},
#  {'rank': '108',
#   'link': '/wiki/Demographics_of_Lebanon',
#   'name': 'Lebanon',
#   'population': '6769000',
#   'percent_of_world': '0.0861'},
#  {'rank': '109',
#   'link': '/wiki/Demographics_of_Kyrgyzstan',
#   'name': 'Kyrgyzstan',
#   'population': '6653600',
#   'percent_of_world': '0.0846'},
#  {'rank': '110',
#   'link': '/wiki/Demographics_of_Nicaragua',
#   'name': 'Nicaragua',
#   'population': '6595674',
#   'percent_of_world': '0.0839'},
#  {'rank': '111',
#   'link': '/wiki/Demographics_of_Turkmenistan',
#   'name': 'Turkmenistan',
#   'population': '6118000',
#   'percent_of_world': '0.0778'},
#  {'rank': '112',
#   'link': '/wiki/Demographics_of_Denmark',
#   'name': 'Denmark',
#   'population': '5840045',
#   'percent_of_world': '0.0742'},
#  {'rank': '113',
#   'link': '/wiki/Demographics_of_Singapore',
#   'name': 'Singapore',
#   'population': '5685807',
#   'percent_of_world': '0.0723'},
#  {'rank': '114',
#   'link': '/wiki/Demographics_of_Republic_of_the_Congo',
#   'name': 'Congo',
#   'population': '5657000',
#   'percent_of_world': '0.0719'},
#  {'rank': '115',
#   'link': '/wiki/Demographics_of_Central_African_Republic',
#   'name': 'Central African Republic',
#   'population': '5633412',
#   'percent_of_world': '0.0716'},
#  {'rank': '116',
#   'link': '/wiki/Demographics_of_Finland',
#   'name': 'Finland',
#   'population': '5506915',
#   'percent_of_world': '0.0700'},
#  {'rank': '117',
#   'link': '/wiki/Demographics_of_Slovakia',
#   'name': 'Slovakia',
#   'population': '5459781',
#   'percent_of_world': '0.0694'},
#  {'rank': '118',
#   'link': '/wiki/Demographics_of_Norway',
#   'name': 'Norway',
#   'population': '5391369',
#   'percent_of_world': '0.0685'},
#  {'rank': '119',
#   'link': '/wiki/Demographics_of_Palestine',
#   'name': '',
#   'population': '5227193',
#   'percent_of_world': '0.0665'},
#  {'rank': '120',
#   'link': '/wiki/Demographics_of_Costa_Rica',
#   'name': 'Costa Rica',
#   'population': '5163038',
#   'percent_of_world': '0.0656'},
#  {'rank': '121',
#   'link': '/wiki/Demographics_of_New_Zealand',
#   'name': 'New Zealand',
#   'population': '5127110',
#   'percent_of_world': '0.0652'},
#  {'rank': '122',
#   'link': '/wiki/Demographics_of_the_Republic_of_Ireland',
#   'name': 'Ireland',
#   'population': '4977400',
#   'percent_of_world': '0.0633'},
#  {'rank': '123',
#   'link': '/wiki/Demographics_of_Liberia',
#   'name': 'Liberia',
#   'population': '4661010',
#   'percent_of_world': '0.0593'},
#  {'rank': '124',
#   'link': '/wiki/Demographics_of_Oman',
#   'name': 'Oman',
#   'population': '4507323',
#   'percent_of_world': '0.0573'},
#  {'rank': '125',
#   'link': '/wiki/Demographics_of_Kuwait',
#   'name': 'Kuwait',
#   'population': '4464521',
#   'percent_of_world': '0.0568'},
#  {'rank': '126',
#   'link': '/wiki/Demographics_of_Panama',
#   'name': 'Panama',
#   'population': '4278500',
#   'percent_of_world': '0.0544'},
#  {'rank': '127',
#   'link': '/wiki/Demographics_of_Mauritania',
#   'name': 'Mauritania',
#   'population': '4271197',
#   'percent_of_world': '0.0543'},
#  {'rank': '128',
#   'link': '/wiki/Demographics_of_Croatia',
#   'name': 'Croatia',
#   'population': '4047200',
#   'percent_of_world': '0.0515'},
#  {'rank': '129',
#   'link': '/wiki/Demographics_of_Georgia_(country)',
#   'name': 'Georgia',
#   'population': '3716858',
#   'percent_of_world': '0.0473'},
#  {'rank': '130',
#   'link': '/wiki/Demographics_of_Eritrea',
#   'name': 'Eritrea',
#   'population': '3601000',
#   'percent_of_world': '0.0458'},
#  {'rank': '131',
#   'link': '/wiki/Demographics_of_Uruguay',
#   'name': 'Uruguay',
#   'population': '3554915',
#   'percent_of_world': '0.0452'},
#  {'rank': '132',
#   'link': '/wiki/Demographics_of_Mongolia',
#   'name': 'Mongolia',
#   'population': '3375823',
#   'percent_of_world': '0.0429'},
#  {'rank': '133',
#   'link': '/wiki/Demographics_of_Bosnia_and_Herzegovina',
#   'name': 'Bosnia and Herzegovina',
#   'population': '3332593',
#   'percent_of_world': '0.0424'},
#  {'rank': '–',
#   'link': '/wiki/Demographics_of_Puerto_Rico',
#   'name': 'Puerto Rico',
#   'population': '3285874',
#   'percent_of_world': '0.0418'},
#  {'rank': '134',
#   'link': '/wiki/Demographics_of_Armenia',
#   'name': 'Armenia',
#   'population': '2967900',
#   'percent_of_world': '0.0377'},
#  {'rank': '135',
#   'link': '/wiki/Demographics_of_Albania',
#   'name': 'Albania',
#   'population': '2845955',
#   'percent_of_world': '0.0362'},
#  {'rank': '136',
#   'link': '/wiki/Demographics_of_Lithuania',
#   'name': 'Lithuania',
#   'population': '2787658',
#   'percent_of_world': '0.0354'},
#  {'rank': '137',
#   'link': '/wiki/Demographics_of_Jamaica',
#   'name': 'Jamaica',
#   'population': '2734093',
#   'percent_of_world': '0.0348'},
#  {'rank': '138',
#   'link': '/wiki/Demographics_of_Qatar',
#   'name': 'Qatar',
#   'population': '2642112',
#   'percent_of_world': '0.0336'},
#  {'rank': '139',
#   'link': '/wiki/Demographics_of_Moldova',
#   'name': 'Moldova',
#   'population': '2640438',
#   'percent_of_world': '0.0336'},
#  {'rank': '140',
#   'link': '/wiki/Demographics_of_Namibia',
#   'name': 'Namibia',
#   'population': '2550226',
#   'percent_of_world': '0.0324'},
#  {'rank': '141',
#   'link': '/wiki/Demographics_of_Botswana',
#   'name': 'Botswana',
#   'population': '2410338',
#   'percent_of_world': '0.0306'},
#  {'rank': '142',
#   'link': '/wiki/Demographics_of_The_Gambia',
#   'name': 'Gambia',
#   'population': '2335504',
#   'percent_of_world': '0.0297'},
#  {'rank': '143',
#   'link': '/wiki/Demographics_of_Gabon',
#   'name': 'Gabon',
#   'population': '2233272',
#   'percent_of_world': '0.0284'},
#  {'rank': '144',
#   'link': '/wiki/Demographics_of_Slovenia',
#   'name': 'Slovenia',
#   'population': '2108977',
#   'percent_of_world': '0.0268'},
#  {'rank': '145',
#   'link': '/wiki/Demographics_of_North_Macedonia',
#   'name': 'North Macedonia',
#   'population': '2076255',
#   'percent_of_world': '0.0264'},
#  {'rank': '146',
#   'link': '/wiki/Demographics_of_Lesotho',
#   'name': 'Lesotho',
#   'population': '2007201',
#   'percent_of_world': '0.0255'},
#  {'rank': '147',
#   'link': '/wiki/Demographics_of_Latvia',
#   'name': 'Latvia',
#   'population': '1889000',
#   'percent_of_world': '0.0240'},
#  {'rank': '–',
#   'link': '/wiki/Demographics_of_Kosovo',
#   'name': 'Kosovo',
#   'population': '1782115',
#   'percent_of_world': '0.0227'},
#  {'rank': '148',
#   'link': '/wiki/Demographics_of_Guinea-Bissau',
#   'name': 'Guinea-Bissau',
#   'population': '1646077',
#   'percent_of_world': '0.0209'},
#  {'rank': '149',
#   'link': '/wiki/Demographics_of_Equatorial_Guinea',
#   'name': 'Equatorial Guinea',
#   'population': '1505588',
#   'percent_of_world': '0.0191'},
#  {'rank': '150',
#   'link': '/wiki/Demographics_of_Bahrain',
#   'name': 'Bahrain',
#   'population': '1501635',
#   'percent_of_world': '0.0191'},
#  {'rank': '151',
#   'link': '/wiki/Demographics_of_Trinidad_and_Tobago',
#   'name': 'Trinidad and Tobago',
#   'population': '1366725',
#   'percent_of_world': '0.0174'},
#  {'rank': '152',
#   'link': '/wiki/Demographics_of_Estonia',
#   'name': 'Estonia',
#   'population': '1329460',
#   'percent_of_world': '0.0169'},
#  {'rank': '153',
#   'link': '/wiki/Demographics_of_East_Timor',
#   'name': 'East Timor',
#   'population': '1317780',
#   'percent_of_world': '0.0168'},
#  {'rank': '154',
#   'link': '/wiki/Demographics_of_Mauritius',
#   'name': 'Mauritius',
#   'population': '1266030',
#   'percent_of_world': '0.0161'},
#  {'rank': '155',
#   'link': '/wiki/Demographics_of_Eswatini',
#   'name': 'Eswatini',
#   'population': '1093238',
#   'percent_of_world': '0.0139'},
#  {'rank': '156',
#   'link': '/wiki/Demographics_of_Djibouti',
#   'name': 'Djibouti',
#   'population': '976107',
#   'percent_of_world': '0.0124'},
#  {'rank': '157',
#   'link': '/wiki/Demographics_of_Fiji',
#   'name': 'Fiji',
#   'population': '898402',
#   'percent_of_world': '0.0114'},
#  {'rank': '158',
#   'link': '/wiki/Demographics_of_Cyprus',
#   'name': 'Cyprus',
#   'population': '888005',
#   'percent_of_world': '0.0113'},
#  {'rank': '159',
#   'link': '/wiki/Demographics_of_Comoros',
#   'name': 'Comoros',
#   'population': '758316',
#   'percent_of_world': '0.00964'},
#  {'rank': '160',
#   'link': '/wiki/Demographics_of_Bhutan',
#   'name': 'Bhutan',
#   'population': '756129',
#   'percent_of_world': '0.00961'},
#  {'rank': '161',
#   'link': '/wiki/Demographics_of_Guyana',
#   'name': 'Guyana',
#   'population': '743699',
#   'percent_of_world': '0.00945'},
#  {'rank': '162',
#   'link': '/wiki/Demographics_of_Solomon_Islands',
#   'name': 'Solomon Islands',
#   'population': '728041',
#   'percent_of_world': '0.00926'},
#  {'rank': '–',
#   'link': '/wiki/Demographics_of_Macau',
#   'name': 'Macau',
#   'population': '683100',
#   'percent_of_world': '0.00868'},
#  {'rank': '163',
#   'link': '/wiki/Demographics_of_Luxembourg',
#   'name': 'Luxembourg',
#   'population': '634730',
#   'percent_of_world': '0.00807'},
#  {'rank': '164',
#   'link': '/wiki/Demographics_of_Montenegro',
#   'name': 'Montenegro',
#   'population': '621873',
#   'percent_of_world': '0.00791'},
#  {'rank': '–',
#   'link': '/wiki/Demographics_of_Western_Sahara',
#   'name': 'Western Sahara',
#   'population': '612000',
#   'percent_of_world': '0.00778'},
#  {'rank': '165',
#   'link': '/wiki/Demographics_of_Suriname',
#   'name': 'Suriname',
#   'population': '590100',
#   'percent_of_world': '0.00750'},
#  {'rank': '166',
#   'link': '/wiki/Demographics_of_Cape_Verde',
#   'name': 'Cape Verde',
#   'population': '563198',
#   'percent_of_world': '0.00716'},
#  {'rank': '167',
#   'link': '/wiki/Demographics_of_Malta',
#   'name': 'Malta',
#   'population': '514564',
#   'percent_of_world': '0.00654'},
#  {'rank': '–',
#   'link': '/wiki/Demographics_of_Transnistria',
#   'name': 'Transnistria',
#   'population': '469000',
#   'percent_of_world': '0.00596'},
#  {'rank': '168',
#   'link': '/wiki/Demographics_of_Brunei',
#   'name': 'Brunei',
#   'population': '453600',
#   'percent_of_world': '0.00577'},
#  {'rank': '169',
#   'link': '/wiki/Demographics_of_Belize',
#   'name': 'Belize',
#   'population': '419199',
#   'percent_of_world': '0.00533'},
#  {'rank': '170',
#   'link': '/wiki/Demographics_of_The_Bahamas',
#   'name': 'Bahamas',
#   'population': '393450',
#   'percent_of_world': '0.00500'},
#  {'rank': '171',
#   'link': '/wiki/Demographics_of_Maldives',
#   'name': 'Maldives',
#   'population': '383135',
#   'percent_of_world': '0.00487'},
#  {'rank': '–',
#   'link': '/wiki/Demographics_of_Northern_Cyprus',
#   'name': 'Northern Cyprus',
#   'population': '372486',
#   'percent_of_world': '0.00474'},
#  {'rank': '172',
#   'link': '/wiki/Demographics_of_Iceland',
#   'name': 'Iceland',
#   'population': '369870',
#   'percent_of_world': '0.00470'},
#  {'rank': '173',
#   'link': '/wiki/Demographics_of_Vanuatu',
#   'name': 'Vanuatu',
#   'population': '301295',
#   'percent_of_world': '0.00383'},
#  {'rank': '174',
#   'link': '/wiki/Demographics_of_Barbados',
#   'name': 'Barbados',
#   'population': '288000',
#   'percent_of_world': '0.00366'},
#  {'rank': '–',
#   'link': '/wiki/Demographics_of_French_Polynesia',
#   'name': 'French Polynesia',
#   'population': '279890',
#   'percent_of_world': '0.00356'},
#  {'rank': '–',
#   'link': '/wiki/Demographics_of_New_Caledonia',
#   'name': 'New Caledonia',
#   'population': '273674',
#   'percent_of_world': '0.00348'},
#  {'rank': '–',
#   'link': '/wiki/Demographics_of_Abkhazia',
#   'name': 'Abkhazia',
#   'population': '245424',
#   'percent_of_world': '0.00312'},
#  {'rank': '175',
#   'link': '/wiki/Demographics_of_S%C3%A3o_Tom%C3%A9_and_Pr%C3%ADncipe',
#   'name': 'São Tomé and Príncipe',
#   'population': '214610',
#   'percent_of_world': '0.00273'},
#  {'rank': '176',
#   'link': '/wiki/Demographics_of_Samoa',
#   'name': 'Samoa',
#   'population': '199853',
#   'percent_of_world': '0.00254'},
#  {'rank': '177',
#   'link': '/wiki/Demographics_of_Saint_Lucia',
#   'name': 'Saint Lucia',
#   'population': '178696',
#   'percent_of_world': '0.00227'},
#  {'rank': '–',
#   'link': '/wiki/Demographics_of_Guam',
#   'name': 'Guam',
#   'population': '178306',
#   'percent_of_world': '0.00227'},
#  {'rank': '–',
#   'link': '/wiki/Demographics_of_Cura%C3%A7ao',
#   'name': 'Curaçao',
#   'population': '156223',
#   'percent_of_world': '0.00199'},
#  {'rank': '–',
#   'link': '/wiki/Republic_of_Artsakh',
#   'name': 'Republic of Artsakh',
#   'population': '148800',
#   'percent_of_world': '0.00189'},
#  {'rank': '178',
#   'link': '/wiki/Demographics_of_Kiribati',
#   'name': 'Kiribati',
#   'population': '120740',
#   'percent_of_world': '0.00154'},
#  {'rank': '179',
#   'link': '/wiki/Demographics_of_Grenada',
#   'name': 'Grenada',
#   'population': '113000',
#   'percent_of_world': '0.00144'},
#  {'rank': '–',
#   'link': '/wiki/Demographics_of_Aruba',
#   'name': 'Aruba',
#   'population': '111904',
#   'percent_of_world': '0.00142'},
#  {'rank': '180',
#   'link': '/wiki/Demographics_of_Saint_Vincent_and_the_Grenadines',
#   'name': 'Saint Vincent and the Grenadines',
#   'population': '110696',
#   'percent_of_world': '0.00141'},
#  {'rank': '–',
#   'link': '/wiki/Demographics_of_Jersey',
#   'name': 'Jersey',
#   'population': '107800',
#   'percent_of_world': '0.00137'},
#  {'rank': '181',
#   'link': '/wiki/Demographics_of_Federated_States_of_Micronesia',
#   'name': 'F.S. Micronesia',
#   'population': '105754',
#   'percent_of_world': '0.00134'},
#  {'rank': '–',
#   'link': '/wiki/Demographics_of_United_States_Virgin_Islands',
#   'name': 'U.S. Virgin Islands',
#   'population': '104000',
#   'percent_of_world': '0.00132'},
#  {'rank': '182',
#   'link': '/wiki/Demographics_of_Tonga',
#   'name': 'Tonga',
#   'population': '99532',
#   'percent_of_world': '0.00127'},
#  {'rank': '183',
#   'link': '/wiki/Demographics_of_Antigua_and_Barbuda',
#   'name': 'Antigua and Barbuda',
#   'population': '99337',
#   'percent_of_world': '0.00126'},
#  {'rank': '184',
#   'link': '/wiki/Demographics_of_Seychelles',
#   'name': 'Seychelles',
#   'population': '98963',
#   'percent_of_world': '0.00126'},
#  {'rank': '–',
#   'link': '/wiki/Demographics_of_Isle_of_Man',
#   'name': 'Isle of Man',
#   'population': '83314',
#   'percent_of_world': '0.00106'},
#  {'rank': '185',
#   'link': '/wiki/Demographics_of_Andorra',
#   'name': 'Andorra',
#   'population': '78015',
#   'percent_of_world': '0.000992'},
#  {'rank': '186',
#   'link': '/wiki/Demographics_of_Dominica',
#   'name': 'Dominica',
#   'population': '72000',
#   'percent_of_world': '0.000915'},
#  {'rank': '–',
#   'link': '/wiki/Demographics_of_the_Cayman_Islands',
#   'name': 'Cayman Islands',
#   'population': '65786',
#   'percent_of_world': '0.000836'},
#  {'rank': '–',
#   'link': '/wiki/Demographics_of_Bermuda',
#   'name': 'Bermuda',
#   'population': '64055',
#   'percent_of_world': '0.000814'},
#  {'rank': '–',
#   'link': '/wiki/Demographics_of_Guernsey',
#   'name': 'Guernsey',
#   'population': '63155',
#   'percent_of_world': '0.000803'},
#  {'rank': '–',
#   'link': '/wiki/Demographics_of_American_Samoa',
#   'name': 'American Samoa',
#   'population': '56951',
#   'percent_of_world': '0.000724'},
#  {'rank': '–',
#   'link': '/wiki/Demographics_of_the_Northern_Mariana_Islands',
#   'name': 'Northern Mariana Islands',
#   'population': '56801',
#   'percent_of_world': '0.000722'},
#  {'rank': '–',
#   'link': '/wiki/Demographics_of_Greenland',
#   'name': 'Greenland',
#   'population': '56421',
#   'percent_of_world': '0.000717'},
#  {'rank': '187',
#   'link': '/wiki/Demographics_of_Marshall_Islands',
#   'name': 'Marshall Islands',
#   'population': '54516',
#   'percent_of_world': '0.000693'},
#  {'rank': '188',
#   'link': '/wiki/Demographics_of_Saint_Kitts_and_Nevis',
#   'name': 'Saint Kitts and Nevis',
#   'population': '54000',
#   'percent_of_world': '0.000687'},
#  {'rank': '–',
#   'link': '/wiki/Demographics_of_South_Ossetia',
#   'name': 'South Ossetia',
#   'population': '53532',
#   'percent_of_world': '0.000681'},
#  {'rank': '–',
#   'link': '/wiki/Demographics_of_Faroe_Islands',
#   'name': 'Faroe Islands',
#   'population': '53108',
#   'percent_of_world': '0.000675'},
#  {'rank': '–',
#   'link': '/wiki/Demographics_of_Turks_and_Caicos_Islands',
#   'name': 'Turks and Caicos Islands',
#   'population': '42953',
#   'percent_of_world': '0.000546'},
#  {'rank': '–',
#   'link': '/wiki/Demographics_of_Sint_Maarten',
#   'name': 'Sint Maarten',
#   'population': '40614',
#   'percent_of_world': '0.000516'},
#  {'rank': '189',
#   'link': '/wiki/Demographics_of_Liechtenstein',
#   'name': 'Liechtenstein',
#   'population': '39062',
#   'percent_of_world': '0.000497'},
#  {'rank': '190',
#   'link': '/wiki/Demographics_of_Monaco',
#   'name': 'Monaco',
#   'population': '38350',
#   'percent_of_world': '0.000488'},
#  {'rank': '–',
#   'link': '/wiki/Collectivity_of_Saint_Martin',
#   'name': '',
#   'population': '34065',
#   'percent_of_world': '0.000433'},
#  {'rank': '–',
#   'link': '/wiki/Demographics_of_Gibraltar',
#   'name': 'Gibraltar',
#   'population': '34003',
#   'percent_of_world': '0.000432'},
#  {'rank': '191',
#   'link': '/wiki/Demographics_of_San_Marino',
#   'name': 'San Marino',
#   'population': '33604',
#   'percent_of_world': '0.000427'},
#  {'rank': '–',
#   'link': '/wiki/%C3%85land_Islands',
#   'name': 'Åland Islands',
#   'population': '30201',
#   'percent_of_world': '0.000384'},
#  {'rank': '–',
#   'link': '/wiki/Demographics_of_the_British_Virgin_Islands',
#   'name': 'British Virgin Islands',
#   'population': '30000',
#   'percent_of_world': '0.000381'},
#  {'rank': '192',
#   'link': '/wiki/Demographics_of_Palau',
#   'name': 'Palau',
#   'population': '17957',
#   'percent_of_world': '0.000228'},
#  {'rank': '–',
#   'link': '/wiki/Demographics_of_Cook_Islands',
#   'name': 'Cook Islands',
#   'population': '15342',
#   'percent_of_world': '0.000195'},
#  {'rank': '–',
#   'link': '/wiki/Demographics_of_Anguilla',
#   'name': 'Anguilla',
#   'population': '15000',
#   'percent_of_world': '0.000191'},
#  {'rank': '193',
#   'link': '/wiki/Demographics_of_Nauru',
#   'name': 'Nauru',
#   'population': '11832',
#   'percent_of_world': '0.000150'},
#  {'rank': '–',
#   'link': '/wiki/Demographics_of_Wallis_and_Futuna',
#   'name': 'Wallis and Futuna',
#   'population': '11369',
#   'percent_of_world': '0.000145'},
#  {'rank': '194',
#   'link': '/wiki/Demographics_of_Tuvalu',
#   'name': 'Tuvalu',
#   'population': '10679',
#   'percent_of_world': '0.000136'},
#  {'rank': '–',
#   'link': '/wiki/Demographics_of_Saint_Barth%C3%A9lemy',
#   'name': 'Saint Barthélemy',
#   'population': '10124',
#   'percent_of_world': '0.000129'},
#  {'rank': '–',
#   'link': '/wiki/Demographics_of_Saint_Pierre_and_Miquelon',
#   'name': 'Saint Pierre and Miquelon',
#   'population': '5985',
#   'percent_of_world': '0'},
#  {'rank': '–',
#   'link': '/wiki/Demographics_of_Saint_Helena,_Ascension_and_Tristan_da_Cunha',
#   'name': 'Saint Helena, Ascensionand Tristan da Cunha',
#   'population': '5633',
#   'percent_of_world': '0'},
#  {'rank': '–',
#   'link': '/wiki/Demographics_of_Montserrat',
#   'name': 'Montserrat',
#   'population': '5000',
#   'percent_of_world': '0'},
#  {'rank': '–',
#   'link': '/wiki/Demographics_of_Falkland_Islands',
#   'name': 'Falkland Islands',
#   'population': '3398',
#   'percent_of_world': '0'},
#  {'rank': '–',
#   'link': '/wiki/Demographics_of_Christmas_Island',
#   'name': 'Christmas Island',
#   'population': '1966',
#   'percent_of_world': '00'},
#  {'rank': '–',
#   'link': '/wiki/Demographics_of_Norfolk_Island',
#   'name': 'Norfolk Island',
#   'population': '1734',
#   'percent_of_world': '00'},
#  {'rank': '–',
#   'link': '/wiki/Demographics_of_Niue',
#   'name': 'Niue',
#   'population': '1549',
#   'percent_of_world': '0'},
#  {'rank': '–',
#   'link': '/wiki/Demographics_of_Tokelau',
#   'name': 'Tokelau',
#   'population': '1501',
#   'percent_of_world': '0'},
#  {'rank': '195',
#   'link': '/wiki/Demographics_of_Vatican_City',
#   'name': 'Vatican City',
#   'population': '825',
#   'percent_of_world': '0'},
#  {'rank': '–',
#   'link': '/wiki/Demographics_of_Cocos_(Keeling)_Islands',
#   'name': 'Cocos (Keeling) Islands',
#   'population': '573',
#   'percent_of_world': '0'},
#  {'rank': '–',
#   'link': '/wiki/Demographics_of_Pitcairn_Islands',
#   'name': 'Pitcairn Islands',
#   'population': '40',
#   'percent_of_world': '0'}]

# %%
country_list_df = pd.DataFrame(country_list)
country_list_df
# Out:
#     rank                                           link  \
# 0      1                    /wiki/Demographics_of_China
# 1      2                    /wiki/Demographics_of_India
# 2      3        /wiki/Demographics_of_the_United_States
# 3      4                /wiki/Demographics_of_Indonesia
# 4      5                 /wiki/Demographics_of_Pakistan
# ..   ...                                            ...
# 236    –                     /wiki/Demographics_of_Niue
# 237    –                  /wiki/Demographics_of_Tokelau
# 238  195             /wiki/Demographics_of_Vatican_City
# 239    –  /wiki/Demographics_of_Cocos_(Keeling)_Islands
# 240    –         /wiki/Demographics_of_Pitcairn_Islands
#
#                         name  population percent_of_world
# 0                      China  1407809120             17.9
# 1                      India  1376560090             17.5
# 2              United States   331616914             4.22
# 3                  Indonesia   271350000             3.45
# 4                   Pakistan   225200000             2.86
# ..                       ...         ...              ...
# 236                     Niue        1549                0
# 237                  Tokelau        1501                0
# 238             Vatican City         825                0
# 239  Cocos (Keeling) Islands         573                0
# 240         Pitcairn Islands          40                0
#
# [241 rows x 5 columns]

# %% [markdown]
# # (Step 2) Use the relative links to scrape the country sites
#
# 1. Read the country_list csv into a Pandas DataFrame
# 2. Visit the link of each country and scrape the tables
# 3. If that page has an information table **in the "correct" format**, retrieve the table rows
# 4. for each country build a dictionary of demographics
#
# <img src="https://i.imgur.com/T9OASLH.png" width="80%">.

# %% [markdown]
# ### The python functions below read in the country CSV, go to each link, scrape the individual country page, and put this information into a list of dictionaries

# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests

def get_country_page(country_link):
    """
    takes in a country demographics URL
    returns beautiful soup object of the HTML page
    """
    country_url = 'https://en.wikipedia.org' + country_link
    response = requests.get(country_url)
    if response.status_code != 200: 
        raise Exception('Failed to fetch web page ' + country_url)
    soup = BeautifulSoup(response.text)
    return soup

# next get every row that has a <th> tag as the first header
def get_row_data(table_rows):
    """
    takes in a list of all the html rows of the table
    returns a dictionary of all key values from each row
    """
    info = {}
    for row in table_rows[1:]:    #skip the first row because it is just the table title
        if (row.td == None):      #then it is a header and we stop scraping
            break  
        elif row.td.has_attr('class'):                 #if no 'class' this not a row we want
            if (row.td['class'][0] == 'infobox-data'): # list value for key so get [0]th element
                info[row.th.text] = row.td.text        # make dict item in list
    return info

def get_demographics(country_link):
    """
    takes in the country link for demographics Wiki
    returns a dictionary with the items from the info table
    """
    soup = get_country_page(country_link)          #retrieves the Beautiful soup Page
    table = soup.find('table', class_='infobox')   #finds the first table in the page
    if table:
        if table.has_attr('style') and table.has_attr('class'):
            table_rows = table.find_all('tr')
            info = get_row_data(table_rows)
            return info
    return   #None if country link does not contain the table we want

def build_country_dictionaries(csv_path):
    """
    takes in a csv file with country demographics links
    returns a list of dictionaries
    each dictionary contains the scraped data for a specific country
    """
    country_df = pd.read_csv(csv_path)
    demo_links = country_df['link']
    table = []
    for link in demo_links:
        temp = get_demographics(link)
        if temp == None: # the site did not a table formated to fit my scraping code
            continue
        else: #then we got some data frpm a table -- add that plus country name to the dictionary list
            temp['Country'] = country_df.loc[country_df['link'] == link, 'name'].item()
            table.append(temp)
    return table

# %% [markdown]
# ### Let's look at all the information we get

# %%
raw_country_dicts = build_country_dictionaries('country_list.csv')

# %% [markdown]
# ### This looks like the information we are interested in...

# %%
raw_country_dicts[5]
# Out:
# {'Population': '144,386,830 (excluding Crimea),[1]  146,748,590 (including Crimea)[1]',
#  'Life expectancy': ' 73.34 years (2019)[2]',
#  '\xa0•\xa0male': '67.75 years (2018)[3]',
#  '\xa0•\xa0female': '77.82 years (2018)[3]',
#  'Fertility rate': ' 1.507 (2019)[4]',
#  'Infant mortality rate': '4.9 deaths/1,000 live births (2019)[5]',
#  'Net migration rate': '1.69 migrant(s)/1,000 population (2014)',
#  'Country': 'Russia'}

# %% [markdown]
# ### ... But not all county data contains the same information

# %%
raw_country_dicts[47]
# Out:
# {'Population': '4,761,865 (2016 census)',
#  'Density': '68 per km2',
#  'Growth rate': '1.77%',
#  'Birth rate': '13.7 births/1,000 population',
#  'Death rate': '6.5 deaths/1,000 population',
#  'Life expectancy': '80.19 years',
#  '\xa0•\xa0male': '78 years',
#  '\xa0•\xa0female': '82.6 years',
#  'Fertility rate': '1.91 children born/woman',
#  'Infant mortality rate': '3.85 deaths/1,000 live births',
#  'Net migration rate': '0.86 migrant(s)/1,000 population',
#  'Country': 'Ireland'}

# %% [markdown]
# ### Some countries did note have any of the info we expected in the table

# %%
raw_country_dicts[44]
# Out:
# {'Country': 'Nicaragua'}

# %% [markdown]
# ### Small country cites had the table but did not have standard country information at all

# %%
raw_country_dicts[79]
# Out:
# {'Sovereign state': 'Australia',
#  'Annexed by the United Kingdom': '1857',
#  'Transferred from Singaporeto Australia': '23 November 1955',
#  'Capital': 'West Island12°11′13″S 96°49′42″E\ufeff / \ufeff12.18694°S 96.82833°E\ufeff / -12.18694; 96.82833',
#  'Largest village': 'Bantam (Home Island)',
#  'Official languages': 'None',
#  'Spoken languages': 'MalayEnglish[a]',
#  'Government': 'Directly administered dependency',
#  '•\xa0Monarch ': 'Elizabeth II',
#  '•\xa0Governor-General ': 'David Hurley',
#  '•\xa0Administrator ': 'Natasha Griggs',
#  '•\xa0Shire President ': 'Seri Wati Iku',
#  'Country': 'Cocos (Keeling) Islands'}

# %% [markdown]
# ### To look at this a bit more quantatively we put everything into a Pandas Dataframe

# %%
raw_df = pd.DataFrame(raw_country_dicts)
raw_df.head()
# Out:
#                                           Population  \
# 0                               1,407,562,280\n(1st)
# 1               1,390,885,000\n(April, 2021 est.)[1]
# 2  308,401,808\n(2010 Census[a]) (3rd)\n\n• Estim...
# 3                             222,903,998 (2020) [1]
# 4                      161,376,708 (2018 est.)[1][2]
#
#                   Growth rate                                    Birth rate  \
# 0   0.59% (2016 est.) (159th)           11.673 births per 1,000 (2019 est.)
# 1         1.2% (2020 est.)[2]   18.2 births/1,000 population (2020 est.)[2]
# 2             0.72% (2020)[1]        11.6 births/1,000 population (2020)[1]
# 3              2.00 (2021)[2]      29.8 births / 1,000 population (2016)[2]
# 4        1.01% (2020 est.)[3]  17.71 births/1,000 population (2020 est.)[3]
#
#                                     Death rate            Life expectancy  \
# 0                7.261 deaths per 1,000 (2019)          76.5 years (2019)
# 1   7.3 deaths/1,000 population (2020 est.)[2]  69.7 years (2020 est.)[2]
# 2        8.9 deaths/1,000 population (2020)[1]       77.8 years (2020)[2]
# 3      7.5 deaths / 1,000 population (2016)[2]       70.0 years (2020)[3]
# 4  5.54 deaths/1,000 population (2020 est.)[3]      72.72 years (2020)[3]
#
#                       • male                   • female  \
# 0          74.4 years (2018)          78.6 years (2018)
# 1  68.4 years (2020 est.)[2]  71.2 years (2020 est.)[2]
# 2              75.1 years[2]              80.5 years[2]
# 3       69.9 years (2020)[3]        70.1 years(2020)[3]
# 4                 71.1 years                 74.4 years
#
#                             Fertility rate  \
# 0            1.5 children per woman (2018)
# 1       2.17 children born/woman (2017)[3]
# 2      1.706 children born/woman (2019)[3]
# 3     3.56 children born / woman (2016)[3]
# 4  2.00 children born/woman (2020 est.)[3]
#
#                            Infant mortality rate        Country  ...  \
# 0       9.595 deaths per 1000 live births (2019)          China  ...
# 1       29.94 deaths/1,000 live births (2018)[4]          India  ...
# 2                                            NaN  United States  ...
# 3     53.86 deaths / 1,000 live births (2016)[3]       Pakistan  ...
# 4  24.73 deaths/1,000 live births (2020 est.)[3]     Bangladesh  ...
#
#   British colony Assigned to New Zealand New Zealand sovereignty  \
# 0            NaN                     NaN                     NaN
# 1            NaN                     NaN                     NaN
# 2            NaN                     NaN                     NaN
# 3            NaN                     NaN                     NaN
# 4            NaN                     NaN                     NaN
#
#   • Ulu-o-Tokelau  • Sovereign entity  • Sovereign  • Secretary of State   \
# 0              NaN                 NaN          NaN                   NaN
# 1              NaN                 NaN          NaN                   NaN
# 2              NaN                 NaN          NaN                   NaN
# 3              NaN                 NaN          NaN                   NaN
# 4              NaN                 NaN          NaN                   NaN
#
#   • President of the Governorate  Annexed by the United Kingdom  \
# 0                             NaN                           NaN
# 1                             NaN                           NaN
# 2                             NaN                           NaN
# 3                             NaN                           NaN
# 4                             NaN                           NaN
#
#   Largest village
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 92 columns]

# %% [markdown]
# ### There are 92 different headings (!) for 80 countries scraped

# %%
len(raw_df.columns.values), len(raw_country_dicts)
# Out:
# (92, 80)

# %% [markdown]
# ### We are not interested in those which are country specific

# %%
#These are some values we are not interested in sorting through
raw_df.columns.values[40:90]
# Out:
# array(['Federation', 'Separate colony', 'Capital', 'Largest city',
#        'Ethnic\xa0groups ', '•\xa0Deputy Governor ',
#        '•\xa0Prime Minister of the UK ', '•\xa0Premier ',
#        'Partition of island', 'Separated from Guadeloupe',
#        '•\xa0President of France ', '•\xa0Prefect ',
#        '•\xa0President of theTerritorial Council ', 'Autonomy granted',
#        'First Regional Assembly (Autonomy Day)', 'EU accession',
#        'Colony established', 'Swedish purchase', 'Returned to France',
#        'Collectivity status',
#        '•\xa0President of the Territorial Council ', '•\xa0Deputy ',
#        '•\xa0Senator ', 'First settlement', 'British rule reasserted',
#        'Falklands War', 'Current constitution',
#        'Capitaland largest settlement', '•\xa0Chief Executive ',
#        'Proclamation of British sovereignty(Annexation)',
#        'Transferred from Singaporeto Australia', 'Spoken languages',
#        '•\xa0Governor-General ', '•\xa0Administrator ',
#        '•\xa0Shire President ', 'Separation from Tasmania',
#        'Transfer to Australia', 'Ethnic\xa0groups  (2016)',
#        'Capitaland largest village', 'Religion ',
#        '•\xa0Representative of the Queen[a] ', 'Protectorate created',
#        'British colony', 'Assigned to New Zealand',
#        'New Zealand sovereignty', '•\xa0Ulu-o-Tokelau ',
#        '•\xa0Sovereign entity ', '•\xa0Sovereign ',
#        '•\xa0Secretary of State ', '•\xa0President of the Governorate '],
#       dtype=object)

# %% [markdown]
# ### We see that we have a variety of information scraped and the keys span over 92 different catagories
# * Many of catagories irregular formatting
# * Only 80 of the 241 websites had a table in the format we found to scrape
# * Some countryies do not have any of the parameters other than the country name
# * Some contain parameters that are of territories and/or contain data that is not general across all countries

# %% [markdown]
# # (Step 3) Cleaning the data

# %% [markdown]
# ### We select the data that is of interest and that is shared with the most countries
#
# 1. Some dictionary keys have special characters in them and need to be modified -- so we will add new key:value pairs for these and delete the old ones
# 2. We will then select a subset of 10 key:value pairs that the country data has and eliminate any country that does not have at least three of these descriptors
#
#   * Population
#   * Growth rate
#   * Birth rate
#   * Death rate
#   * Life expectancy
#   * Fertility rate
#   * Infant mortality rate
#   * Country
#   * male
#   * female
#
#
# 3. For the above keys, we will strip all text and references and percentage signs and commas

# %% [markdown]
# ### Below are the Python functions needed to clean the data that was scraped

# %%
def strip_key_bullets(country_dicts):
    """
    Takes in a list of dictionaries and 
    strips characters from the keys by creation a new k:v
    and poping the unwanted k:v pair
    """
    vals = '•', '\xa0'
    # must use copy of list so keys don't change as we iterate over them
    for index, country in enumerate(country_dicts.copy()): 
        for key in country:
            if vals[0] in key or vals[1] in key:
                country_dicts[index][key.replace(vals[0], '').replace(vals[1], '')] = country[key]
                country_dicts[index].pop(key)
    return country_dicts

def select_keys(country_dicts):
    """ 
    copied wanted elements form each dictioary
    returns the new list of dicts
    """
    keys_to_keep = ('Population', 
                   'Growth rate', 
                   'Birth rate', 
                   'Death rate', 
                   'Life expectancy', 
                   'Fertility rate', 
                   'Infant mortality rate', 
                   'Country', 
                   'male', 
                   'female', 
                   )
    newlist = []
    for country in country_dicts:
        tempdict = {key: country[key] for key in keys_to_keep if country.get(key)}
        if len(tempdict) > 3:         # then it has enough of the entries to make it worth parsing
            newlist.append(tempdict)
    return newlist

def strip_n_split_values(country_dicts):
    for country in country_dicts:
        for key in country:
            if key.lower() == 'country' or country[key] == '': # don't want to split country names
                continue               # we need to handle density and leave the spaces in density
            else:
                country[key] = country[key].split()[0].split('[')[0].split('/')[0]. \
                split('(')[0].strip().strip('‰%').replace(',', '')
    return country_dicts

# %% [markdown]
# ### This line of code below calls the cleaning functions that do almost everything we need

# %%
newdicts = strip_n_split_values(select_keys(strip_key_bullets(raw_country_dicts)))
write_csv('country_demographics.csv', newdicts)

# %%
df = pd.DataFrame(newdicts)
df.head()
# Out:
#    Population Growth rate Birth rate Death rate Life expectancy  \
# 0  1407562280        0.59     11.673      7.261            76.5
# 1  1390885000         1.2       18.2        7.3            69.7
# 2   308401808        0.72       11.6        8.9            77.8
# 3   222903998        2.00       29.8        7.5            70.0
# 4   161376708        1.01      17.71       5.54           72.72
#
#   Fertility rate Infant mortality rate        Country  male female
# 0            1.5                 9.595          China  74.4   78.6
# 1           2.17                 29.94          India  68.4   71.2
# 2          1.706                   NaN  United States  75.1   80.5
# 3           3.56                 53.86       Pakistan  69.9   70.1
# 4           2.00                 24.73     Bangladesh  71.1   74.4

# %% [markdown]
# **We see that 56 of the 80 sites scraped have data in the catagories we selected**

# %%
len(newdicts)
# Out:
# 56

# %% [markdown]
# ### Now we want to find information on where all the NaNs are located

# %%
# sum the nane in every oolumn
sum_nulls = pd.isnull(df).sum()
sum_nulls
# Out:
# Population               1
# Growth rate              4
# Birth rate               1
# Death rate               2
# Life expectancy          2
# Fertility rate           2
# Infant mortality rate    8
# Country                  0
# male                     4
# female                   4
# dtype: int64

# %%
#find the rows (ie countries) that contain NaNs
rows_with_nan = [index for index, row in df.iterrows() if row.isnull().any()]
rows_with_nan, len(rows_with_nan)
# Out:
# ([2, 5, 10, 12, 13, 15, 18, 25, 26, 30, 41, 44, 46, 53, 54], 15)

# %% [markdown]
# # Here is a dataframe of all rows that contain NaNs

# %%
df.iloc[rows_with_nan, :]
# Out:
#    Population Growth rate Birth rate Death rate Life expectancy  \
# 2   308401808        0.72       11.6        8.9            77.8
# 5   144386830         NaN        NaN        NaN           73.34
# 10   83614362        0.55       13.0        NaN            78.6
# 12   67399000         NaN       11.0        9.8            82.2
# 13   66796807         NaN       11.0        9.3              81
# 15   51049498         0.8       18.9        5.8              79
# 18   33091113        1.49       14.7        3.4            75.7
# 25   17474677        0.29        9.8        8.8            82.1
# 26        NaN        1.63       22.5        6.0            69.6
# 30       2015        2.05       23.9        3.4            74.8
# 41    5084300         2.1      12.43       6.95             NaN
# 44    3716858         1.5       14.3       12.8            73.5
# 46    3046100        0.27       2.97       1.76             NaN
# 53     884887         NaN       22.5       8.10            72.1
# 54      37308        2.25       13.1       10.4            84.7
#
#    Fertility rate Infant mortality rate         Country   male female
# 2           1.706                   NaN   United States   75.1   80.5
# 5           1.507                   4.9          Russia  67.75  77.82
# 10           1.73                   8.6          Turkey   75.9   81.3
# 12           1.84                   3.8          France   79.2   85.2
# 13           1.65                   NaN  United Kingdom    NaN    NaN
# 15           1.80                   NaN        Colombia     76     83
# 18           1.95                   NaN    Saudi Arabia   74.2   77.3
# 25          1.574                   NaN     Netherlands   80.4   83.8
# 26           2.66                    24        Cambodia   67.3   71.6
# 30            2.7                   NaN          Jordan   73.4   76.3
# 41           1.81                  3.87     New Zealand   79.9   83.4
# 44            NaN                   8.1         Georgia    NaN    NaN
# 46            NaN                   NaN         Armenia    NaN    NaN
# 53            2.9                  12.5            Fiji   65.4   68.5
# 54           1.52                   NaN          Monaco    NaN    NaN

# %% [markdown]
# ### Ok... We will stop here, ave the files,  and summarize what we have accomplished in this Project

# %%
# let us attach and save the files
import jovian
jovian.commit(filename='webscraping-wiki-country-demographics.ipynb', project='webscraping-wiki-country-demographics', files=['country_demographics.csv','country_list.csv'])
# Out:
# [jovian] Updating notebook "samantha-roberts/webscraping-wiki-country-demographics" on https://jovian.ai/
# [jovian] Uploading additional files...
# [jovian] Committed successfully! https://jovian.ai/samantha-roberts/webscraping-wiki-country-demographics
# 'https://jovian.ai/samantha-roberts/webscraping-wiki-country-demographics'

# %% [markdown]
# ***
# <h1><center>Analysis of our Analysis</center></h1>
#
# ### We have used the Requests API, Beautiful Soup library and Pandas dataframes to do the following:
#
# 1. We scraped a table in wiki to get a list of countries and the links to the demographics pages
# 2. We put these 241 entries into a csv (attached)
# 3. Scrape those 241 pages for a specific style of table with specific format
# 4. 80 demographics pages had the tables that this code could scrape
# 5. We then cleaned the data and found that 56 country pages contained the information we were trying to tablulate
# 6. We read this information into a Pandas Dataframe to look at it further
# 7. Wrote this data to a csv (also attached)
#
# It seems that scraping a wiki site can be more difficult than scraping a site that has a definite standard way of formatting the information in their HTML pages.  Though WikiProjects seeks to standardize this, the table we were scraping only existed in 80 of the 241 pages.  Additionally, even where the table itself existed, it contained data variations in the content and the formatting of the data.  This meant that we had to do some cleaning of the data to be able to create a meaningful CSV file of some key demographics information.
#
# Furthermore, due to people frequently editing the pages, the code for scraping the sites which contained the list of all the countries stopped working and the links have even changed.  This is a risk of all web scrapers but perhaps something to be more concerned with when dealing with Wiki specifically.
#
# This project demonstrates both the usefulness and the limitations of the webscraping method of acquiring data from the web.
#
# Overall -- a fun project!  And now I know what web scraping actually is!

# %% [markdown]
# ## Future Work
# - Learn how to use the [Wikidata SPARQL](https://www.wikidata.org/wiki/Wikidata:SPARQL_tutorial) service to directly query and retrieve data for Wikipedia without web scraping
# - A [wikidata query tutorial](https://rozhon.com/sheets-for-marketers/how-to-extract-data-from-wikipedia-and-wikidata/) by Robin Rozhon
# - [Another tutorial](https://janakiev.com/blog/wikidata-mayors/) on querying Wikidata with Python and SPARQL by Janakiev
#     - This happens to be the one that is most useful, (in my opinion :)

# %% [markdown]
# ## Acknowledgements and References
# - I would like to thank the [Jovian](https://jovian.ai/) team for teaching me everything I know to date about Data Science
# - [Beautiful Soup Documentation](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)

# %% [markdown]
# ## Links to Wikipedia demographics showing various formats:
# **Not all Wiki demographics pages are formated the same - Note examples below**
#
# * This contains a Wiki table listing of all countries in order of population:
#     - [List_of_countries_and_dependencies_by_population](https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population)
#     - We can crawl the links in this table to reach each of the country demographics webpages
#
#
# * Some Wiki Demographics pages like these Have an easy table to access which has the info I want to scrape
#     * [Demographics_of_Switzerland](https://en.wikipedia.org/wiki/Demographics_of_Switzerland)
#     * [Demographics_of_the_United_States](https://en.wikipedia.org/wiki/Demographics_of_the_United_States)
#     * [Demographics_of_Chile](https://en.wikipedia.org/wiki/Demographics_of_Chile)
#
#
# * Some Demographics pages like these have the info in a different format:
#     * [Demography_of_Australia](https://en.wikipedia.org/wiki/Demography_of_Australia)
#
#
# * Some pages like these do not have these specific summary tables at all:
#     * [Demographics_of_Kenya](https://en.wikipedia.org/wiki/Demographics_of_Kenya)
#     * [Demographics_of_Thailand](https://en.wikipedia.org/wiki/Demographics_of_Thailand)
#     * [Demographics_of_Italy](https://en.wikipedia.org/wiki/Demographics_of_Italy)
